# %% [markdown]
# # Uploading and Preprocessing Data

# %%
import pandas as pd
import os
from utils import *
from model import * 
from model_variations import * 
from my_statistics import *
from dynamic_IB_range import *

# %load_ext autoreload
# %autoreload 2

# %%
df_2 = utils.create_and_preprocess_trading_data("2024-01-01", "2024-11-20", True, 'data/data')

# %%
pandas_data_2 = df_2.to_pandas()

# %% [markdown]
# # Dynamic IB Range

# %% [markdown]
# ### Data collection

# %%
consolidation_data = collect_consolidation_data(pandas_data_2, df_2, window=32, range_threshold=4, filter_start_time="8:00:00", filter_end_time="15:59:00")
consolidation_data.insert(5, "breakout_time_pct", consolidation_data["breakout_time"].apply(time_str_to_percentage))

# %%
print(consolidation_data.shape)
consolidation_data.head()
# Out:
# (225, 14)
#         date direction  range_low  range_high breakout_time  \
# 0 2024-01-04      down    4747.00     4751.00      14:04:00
# 1 2024-01-08      down    4736.00     4739.50      08:50:00
# 2 2024-01-08        up    4768.25     4771.75      13:48:00
# 3 2024-01-09      down    4772.75     4776.50      09:18:00
# 4 2024-01-09        up    4794.00     4798.00      12:54:00
#
#    breakout_time_pct  breakout_price  breakout_distance  consolidation_range  \
# 0          75.833333         4746.50                0.5                 4.00
# 1          10.416667         4735.00                1.0                 3.50
# 2          72.500000         4773.25                1.5                 3.50
# 3          16.250000         4772.25                0.5                 3.75
# 4          61.250000         4799.00                1.0                 4.00
#
#   consolidation_duration   std_dev  average_volume  \
# 0        0 days 00:39:00  0.869330     1064.394737
# 1        0 days 00:33:00  0.731630      463.968750
# 2        0 days 00:33:00  0.615451      993.906250
# 3        0 days 00:34:00  0.890754      867.969697
# 4        0 days 00:33:00  0.821676     1189.000000
#
#    average_volume_after_breakout worked?
# 0                         1500.0    True
# 1                          856.0   False
# 2                         2148.0    True
# 3                          838.0    True
# 4                         2401.0    True

# %%
breakout_time_by_trade_outcome(consolidation_data)

# %% [markdown]
# Now I will collect consolidation data based on all possible combinations of the window and range_threshold parameters as defined below.

# %%
windows = [12, 16, 20, 24, 28, 32, 36, 40, 44]
range_thresholds = [2, 3, 4, 5, 6, 7, 8, 9, 10]

# Generate all combinations of hyperparameters
hyperparam_combinations = itertools.product(range_thresholds, windows)

# Dictionary to store model_data DataFrames
model_data_dict = {}

for range_threshold, window in hyperparam_combinations:
    try:
        # Collect consolidation data
        consolidation_data = collect_consolidation_data(pandas_data_2, df_2, window=window, range_threshold=range_threshold,
                                                       filter_start_time="8:00:00", filter_end_time="15:59:00")

        # Check the collected data
        model_data = pd.DataFrame(consolidation_data)
        if model_data.empty:
            print(f"Warning: No data collected for window={window}, range_threshold={range_threshold}")
            continue  # Skip this iteration if no data

        model_data['breakout_time'] = pd.to_datetime(model_data['breakout_time'])

        # Create binary variable for whether the breakout is before or after 12 PM
        model_data['breakout_after_12pm'] = model_data['breakout_time'].dt.hour >= 12
        model_data['breakout_after_12pm'] = model_data['breakout_after_12pm'].astype(int)

        # Calculate features
        model_data['breakout_over_consolidation_volume_ratio'] = model_data['average_volume_after_breakout'] / model_data['average_volume']
        model_data['breakout_relative_size'] = model_data['breakout_distance'] / (model_data['range_high'] - model_data['range_low'])

        # Drop rows with missing target labels
        model_data = model_data.dropna(subset='worked?')
        model_data['worked?'] = model_data['worked?'].astype(int)

        # Select columns for training
        model_data = model_data[['average_volume_after_breakout', 'average_volume', 'breakout_over_consolidation_volume_ratio',
                                 'std_dev', 'breakout_relative_size', 'breakout_after_12pm', 'worked?']]

        # Create a key for each combination of hyperparameters
        param_key = (range_threshold, window)

        print("Data successfully processed for range_threshold ", range_threshold, "and window ", window)

        # Store the model_data DataFrame in the dictionary with the key
        model_data_dict[param_key] = model_data

    except Exception as e:
        print(f"Error processing combination {range_threshold}, {window}: {e}")
        continue

# Now model_data_dict contains a DataFrame for each combination of hyperparameters.
# Out:
# Data successfully processed for range_threshold  2 and window  12
# Data successfully processed for range_threshold  2 and window  16
# Data successfully processed for range_threshold  2 and window  20
# Data successfully processed for range_threshold  2 and window  24
# Data successfully processed for range_threshold  2 and window  28
# Data successfully processed for range_threshold  2 and window  32
# Data successfully processed for range_threshold  2 and window  36
# Data successfully processed for range_threshold  2 and window  40
# Data successfully processed for range_threshold  2 and window  44
# Data successfully processed for range_threshold  3 and window  12
# Data successfully processed for range_threshold  3 and window  16
# Data successfully processed for range_threshold  3 and window  20
# Data successfully processed for range_threshold  3 and window  24
# Data successfully processed for range_threshold  3 and window  28
# Data successfully processed for range_threshold  3 and window  32
# Data successfully processed for range_threshold  3 and window  36
# Data successfully processed for range_threshold  3 and window  40
# Data successfully processed for range_threshold  3 and window  44
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:59:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5589.0, 'range_high': 5592.75, 'consolidation_range': 3.75, 'consolidation_duration': Timedelta('0 days 00:15:00'), 'std_dev': 0.5732115042211108, 'average_volume': 3941.866666666667}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  4 and window  12
# Data successfully processed for range_threshold  4 and window  16
# Data successfully processed for range_threshold  4 and window  20
# Data successfully processed for range_threshold  4 and window  24
# Data successfully processed for range_threshold  4 and window  28
# Data successfully processed for range_threshold  4 and window  32
# Data successfully processed for range_threshold  4 and window  36
# Data successfully processed for range_threshold  4 and window  40
# Data successfully processed for range_threshold  4 and window  44
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:59:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5589.0, 'range_high': 5592.75, 'consolidation_range': 3.75, 'consolidation_duration': Timedelta('0 days 00:15:00'), 'std_dev': 0.5732115042211108, 'average_volume': 3941.866666666667}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  5 and window  12
# Data successfully processed for range_threshold  5 and window  16
# Data successfully processed for range_threshold  5 and window  20
# Data successfully processed for range_threshold  5 and window  24
# Data successfully processed for range_threshold  5 and window  28
# Data successfully processed for range_threshold  5 and window  32
# Data successfully processed for range_threshold  5 and window  36
# Data successfully processed for range_threshold  5 and window  40
# Data successfully processed for range_threshold  5 and window  44
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:59:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5589.0, 'range_high': 5592.75, 'consolidation_range': 3.75, 'consolidation_duration': Timedelta('0 days 00:15:00'), 'std_dev': 0.5732115042211108, 'average_volume': 3941.866666666667}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  6 and window  12
# Data successfully processed for range_threshold  6 and window  16
# Data successfully processed for range_threshold  6 and window  20
# Data successfully processed for range_threshold  6 and window  24
# Data successfully processed for range_threshold  6 and window  28
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:13:00'), 'end_time': Timestamp('2025-03-23 12:46:00'), 'range_low': 5583.5, 'range_high': 5589.5, 'consolidation_range': 6.0, 'consolidation_duration': Timedelta('0 days 00:33:00'), 'std_dev': 1.2308769084314148, 'average_volume': 1914.625}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  6 and window  32
# Data successfully processed for range_threshold  6 and window  36
# Data successfully processed for range_threshold  6 and window  40
# Data successfully processed for range_threshold  6 and window  44
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:06:00'), 'end_time': Timestamp('2025-03-23 12:20:00'), 'range_low': 5582.25, 'range_high': 5589.0, 'consolidation_range': 6.75, 'consolidation_duration': Timedelta('0 days 00:14:00'), 'std_dev': 2.1346875709670083, 'average_volume': 2046.5384615384614}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:53:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5588.75, 'range_high': 5595.75, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:21:00'), 'std_dev': 1.3424169744655843, 'average_volume': 4740.952380952381}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  7 and window  12
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:07:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5582.5, 'range_high': 5589.5, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:44:00'), 'std_dev': 1.8766834450821495, 'average_volume': 2067.8837209302324}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:53:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5588.75, 'range_high': 5595.75, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:21:00'), 'std_dev': 1.3424169744655843, 'average_volume': 4775.809523809524}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  7 and window  16
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:07:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5582.5, 'range_high': 5589.5, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:44:00'), 'std_dev': 1.852555775527324, 'average_volume': 2080.232558139535}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:53:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5588.75, 'range_high': 5595.75, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:21:00'), 'std_dev': 1.3101026859063556, 'average_volume': 4759.9047619047615}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  7 and window  20
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:07:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5582.5, 'range_high': 5589.5, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:44:00'), 'std_dev': 1.881324696460056, 'average_volume': 2042.046511627907}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  7 and window  24
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:36:00'), 'end_time': Timestamp('2025-03-23 11:13:00'), 'range_low': 5321.0, 'range_high': 5328.0, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:37:00'), 'std_dev': 2.169903717416315, 'average_volume': 250.38888888888889}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:07:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5582.5, 'range_high': 5589.5, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:44:00'), 'std_dev': 1.8786739568381423, 'average_volume': 2050.0697674418607}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  7 and window  28
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:37:00'), 'end_time': Timestamp('2025-03-23 11:13:00'), 'range_low': 5321.0, 'range_high': 5328.0, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:36:00'), 'std_dev': 2.085917165222068, 'average_volume': 258.7142857142857}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:07:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5582.5, 'range_high': 5589.5, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:44:00'), 'std_dev': 1.8695148635482106, 'average_volume': 2058.0697674418607}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  7 and window  32
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:07:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5582.5, 'range_high': 5589.5, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:44:00'), 'std_dev': 1.8803679159798194, 'average_volume': 2063.4186046511627}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  7 and window  36
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:38:00'), 'end_time': Timestamp('2025-03-23 11:24:00'), 'range_low': 5321.5, 'range_high': 5328.5, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:46:00'), 'std_dev': 2.102682870174495, 'average_volume': 224.86666666666667}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:07:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5582.5, 'range_high': 5589.5, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:44:00'), 'std_dev': 1.835439995709913, 'average_volume': 2043.4186046511627}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  7 and window  40
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:38:00'), 'end_time': Timestamp('2025-03-23 11:24:00'), 'range_low': 5321.5, 'range_high': 5328.5, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:46:00'), 'std_dev': 2.0906991001272104, 'average_volume': 224.2888888888889}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:07:00'), 'end_time': Timestamp('2025-03-23 12:53:00'), 'range_low': 5582.5, 'range_high': 5589.5, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:46:00'), 'std_dev': 1.8866724220920885, 'average_volume': 2078.711111111111}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  7 and window  44
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:07:00'), 'end_time': Timestamp('2025-03-23 12:20:00'), 'range_low': 5582.5, 'range_high': 5589.0, 'consolidation_range': 6.5, 'consolidation_duration': Timedelta('0 days 00:13:00'), 'std_dev': 2.0646510821223742, 'average_volume': 2094.0}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:51:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5587.75, 'range_high': 5595.75, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:23:00'), 'std_dev': 1.500823226010054, 'average_volume': 4655.347826086957}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  8 and window  12
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:20:00'), 'range_low': 5581.5, 'range_high': 5589.0, 'consolidation_range': 7.5, 'consolidation_duration': Timedelta('0 days 00:17:00'), 'std_dev': 2.0564304632056003, 'average_volume': 1987.625}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:51:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5587.75, 'range_high': 5595.75, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:23:00'), 'std_dev': 1.5015637435318314, 'average_volume': 4726.95652173913}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  8 and window  16
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.0672801179403466, 'average_volume': 2033.8936170212767}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:51:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5587.75, 'range_high': 5595.75, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:23:00'), 'std_dev': 1.5015637435318314, 'average_volume': 4717.608695652174}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  8 and window  20
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.0432279109346076, 'average_volume': 2045.1914893617022}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  8 and window  24
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:34:00'), 'end_time': Timestamp('2025-03-23 11:12:00'), 'range_low': 5320.5, 'range_high': 5327.75, 'consolidation_range': 7.25, 'consolidation_duration': Timedelta('0 days 00:38:00'), 'std_dev': 2.2123348922972026, 'average_volume': 248.43243243243242}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.073563276668854, 'average_volume': 2010.2553191489362}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  8 and window  28
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:37:00'), 'end_time': Timestamp('2025-03-23 11:13:00'), 'range_low': 5321.0, 'range_high': 5328.0, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:36:00'), 'std_dev': 2.085917165222068, 'average_volume': 258.7142857142857}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.0738142070596406, 'average_volume': 2017.595744680851}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  8 and window  32
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.0597150274854976, 'average_volume': 2024.9148936170213}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  8 and window  36
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:31:00'), 'end_time': Timestamp('2025-03-23 11:13:00'), 'range_low': 5320.25, 'range_high': 5328.0, 'consolidation_range': 7.75, 'consolidation_duration': Timedelta('0 days 00:42:00'), 'std_dev': 2.4275633924555384, 'average_volume': 248.29268292682926}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.074399593261973, 'average_volume': 2029.8085106382978}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  8 and window  40
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:32:00'), 'end_time': Timestamp('2025-03-23 11:24:00'), 'range_low': 5320.5, 'range_high': 5328.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:52:00'), 'std_dev': 2.5052396073421956, 'average_volume': 215.01960784313727}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.044840193109513, 'average_volume': 2011.5106382978724}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  8 and window  44
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:06:00'), 'end_time': Timestamp('2025-03-23 12:20:00'), 'range_low': 5582.25, 'range_high': 5589.0, 'consolidation_range': 6.75, 'consolidation_duration': Timedelta('0 days 00:14:00'), 'std_dev': 2.1346875709670083, 'average_volume': 2046.5384615384614}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:51:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5587.75, 'range_high': 5595.75, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:23:00'), 'std_dev': 1.500823226010054, 'average_volume': 4655.347826086957}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  9 and window  12
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:20:00'), 'range_low': 5581.5, 'range_high': 5589.0, 'consolidation_range': 7.5, 'consolidation_duration': Timedelta('0 days 00:17:00'), 'std_dev': 2.0564304632056003, 'average_volume': 1987.625}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:51:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5587.75, 'range_high': 5595.75, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:23:00'), 'std_dev': 1.5015637435318314, 'average_volume': 4726.95652173913}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  9 and window  16
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.0672801179403466, 'average_volume': 2033.8936170212767}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:51:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5587.75, 'range_high': 5595.75, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:23:00'), 'std_dev': 1.5015637435318314, 'average_volume': 4717.608695652174}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  9 and window  20
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.0432279109346076, 'average_volume': 2045.1914893617022}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  9 and window  24
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:34:00'), 'end_time': Timestamp('2025-03-23 11:12:00'), 'range_low': 5320.5, 'range_high': 5327.75, 'consolidation_range': 7.25, 'consolidation_duration': Timedelta('0 days 00:38:00'), 'std_dev': 2.2123348922972026, 'average_volume': 248.43243243243242}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.073563276668854, 'average_volume': 2010.2553191489362}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  9 and window  28
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:37:00'), 'end_time': Timestamp('2025-03-23 11:13:00'), 'range_low': 5321.0, 'range_high': 5328.0, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:36:00'), 'std_dev': 2.085917165222068, 'average_volume': 258.7142857142857}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.0738142070596406, 'average_volume': 2017.595744680851}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  9 and window  32
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.0597150274854976, 'average_volume': 2024.9148936170213}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  9 and window  36
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:22:00'), 'end_time': Timestamp('2025-03-23 11:12:00'), 'range_low': 5319.0, 'range_high': 5327.75, 'consolidation_range': 8.75, 'consolidation_duration': Timedelta('0 days 00:50:00'), 'std_dev': 2.7894892005526746, 'average_volume': 225.3877551020408}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.074399593261973, 'average_volume': 2029.8085106382978}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  9 and window  40
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:22:00'), 'end_time': Timestamp('2025-03-23 11:13:00'), 'range_low': 5319.0, 'range_high': 5328.0, 'consolidation_range': 9.0, 'consolidation_duration': Timedelta('0 days 00:51:00'), 'std_dev': 2.8328250844666836, 'average_volume': 225.7}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.044840193109513, 'average_volume': 2011.5106382978724}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  9 and window  44
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:51:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5587.75, 'range_high': 5595.75, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:23:00'), 'std_dev': 1.500823226010054, 'average_volume': 4655.347826086957}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  10 and window  12
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:20:00'), 'range_low': 5581.5, 'range_high': 5589.0, 'consolidation_range': 7.5, 'consolidation_duration': Timedelta('0 days 00:17:00'), 'std_dev': 2.0564304632056003, 'average_volume': 1987.625}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:51:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5587.75, 'range_high': 5595.75, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:23:00'), 'std_dev': 1.5015637435318314, 'average_volume': 4726.95652173913}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  10 and window  16
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.0672801179403466, 'average_volume': 2033.8936170212767}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:51:00'), 'end_time': Timestamp('2025-03-23 13:14:00'), 'range_low': 5587.75, 'range_high': 5595.75, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:23:00'), 'std_dev': 1.5015637435318314, 'average_volume': 4717.608695652174}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  10 and window  20
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.0432279109346076, 'average_volume': 2045.1914893617022}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  10 and window  24
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:34:00'), 'end_time': Timestamp('2025-03-23 11:12:00'), 'range_low': 5320.5, 'range_high': 5327.75, 'consolidation_range': 7.25, 'consolidation_duration': Timedelta('0 days 00:38:00'), 'std_dev': 2.2123348922972026, 'average_volume': 248.43243243243242}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.073563276668854, 'average_volume': 2010.2553191489362}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  10 and window  28
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:37:00'), 'end_time': Timestamp('2025-03-23 11:13:00'), 'range_low': 5321.0, 'range_high': 5328.0, 'consolidation_range': 7.0, 'consolidation_duration': Timedelta('0 days 00:36:00'), 'std_dev': 2.085917165222068, 'average_volume': 258.7142857142857}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.0738142070596406, 'average_volume': 2017.595744680851}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  10 and window  32
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.0597150274854976, 'average_volume': 2024.9148936170213}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  10 and window  36
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:21:00'), 'end_time': Timestamp('2025-03-23 11:02:00'), 'range_low': 5318.5, 'range_high': 5327.75, 'consolidation_range': 9.25, 'consolidation_duration': Timedelta('0 days 00:41:00'), 'std_dev': 2.398174719902511, 'average_volume': 231.175}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.074399593261973, 'average_volume': 2029.8085106382978}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  10 and window  40
# {'date': Timestamp('2024-05-27 00:00:00'), 'start_time': Timestamp('2025-03-23 10:21:00'), 'end_time': Timestamp('2025-03-23 11:13:00'), 'range_low': 5318.5, 'range_high': 5328.0, 'consolidation_range': 9.5, 'consolidation_duration': Timedelta('0 days 00:52:00'), 'std_dev': 2.8980554670668535, 'average_volume': 222.23529411764707}
# Conditions for checking the output were not met.
# {'date': Timestamp('2024-07-03 00:00:00'), 'start_time': Timestamp('2025-03-23 12:03:00'), 'end_time': Timestamp('2025-03-23 12:51:00'), 'range_low': 5581.5, 'range_high': 5589.5, 'consolidation_range': 8.0, 'consolidation_duration': Timedelta('0 days 00:48:00'), 'std_dev': 2.044840193109513, 'average_volume': 2011.5106382978724}
# Conditions for checking the output were not met.
# Data successfully processed for range_threshold  10 and window  44

# %%
# This code snippet simply saves all of the collected data on consolidations throughout the year in a folder inside of current directory

current_directory = os.getcwd()
folder_name = 'collect_consolidation_data_files'
os.makedirs(folder_name)

# Save each DataFrame inside the folder
for (range_threshold, window), model_data in model_data_dict.items():
    filename = os.path.join(folder_name, f'model_data_{range_threshold}_{window}.csv')
    model_data.to_csv(filename, index=False)

# Change the directory back to the original one
os.chdir(current_directory)

# %% [markdown]
# # Training the data

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
import itertools
import numpy as np

# Regularization hyperparameter (lambda) values as the inverse of regularization strength (C)
lambda_values = [0, 0.01, 0.03, 0.07, 0.1, 0.3, 0.7, 1, 3, 7, 10, 30, 70, 100]  # Example values for regularization strength

# Generate all combinations of hyperparameters (only lambda values in this case)
lambda_combinations = list(itertools.product(lambda_values))

# Store results
results = []

# Loop through the hyperparameter combinations
for (range_threshold, window), model_data in model_data_dict.items():
    for lambda_val in lambda_combinations:
        try:
            # Check if model_data is empty
            if model_data.empty:
                print(f"Warning: No data collected for window={window}, range_threshold={range_threshold}")
                continue  # Skip this iteration if no data

            # Split into features (X) and target (y)
            X = model_data[['average_volume_after_breakout', 'average_volume', 'breakout_over_consolidation_volume_ratio',
                            'std_dev', 'breakout_relative_size', 'breakout_after_12pm']]
            y = model_data['worked?']

            # Set up 5-fold cross-validation
            cv = KFold(n_splits=5, shuffle=True, random_state=42)

            # Lists to store metrics for each fold
            accuracies, precisions, recalls, f1_scores, roc_aucs, log_losses = [], [], [], [], [], []

            # 5-fold cross-validation
            for train_index, test_index in cv.split(X):
                X_train_cv, X_test_cv = X.iloc[train_index], X.iloc[test_index]
                y_train_cv, y_test_cv = y.iloc[train_index], y.iloc[test_index]

                # Scale the features
                scaler = StandardScaler()
                X_train_scaled = scaler.fit_transform(X_train_cv)
                X_test_scaled = scaler.transform(X_test_cv)

                # Train Logistic Regression with regularization strength (lambda)
                log_reg = LogisticRegression(C=1/lambda_val[0], solver='liblinear', random_state=42)
                log_reg.fit(X_train_scaled, y_train_cv)

                # Evaluate the model on the testing fold
                y_pred = log_reg.predict(X_test_scaled)
                y_prob = log_reg.predict_proba(X_test_scaled)[:, 1]

                # Calculate evaluation metrics for the fold
                acc = accuracy_score(y_test_cv, y_pred)
                prec = precision_score(y_test_cv, y_pred)
                rec = recall_score(y_test_cv, y_pred)
                f1_val = f1_score(y_test_cv, y_pred)
                roc_val = roc_auc_score(y_test_cv, y_prob)
                ll = log_loss(y_test_cv, y_prob)

                # Append metrics for each fold
                accuracies.append(acc)
                precisions.append(prec)
                recalls.append(rec)
                f1_scores.append(f1_val)
                roc_aucs.append(roc_val)
                log_losses.append(ll)

            # Calculate the average metrics across all folds
            result = {
                'window': window,
                'range_threshold': range_threshold,
                'lambda': lambda_val[0],
                'accuracy': np.mean(accuracies),
                'precision': np.mean(precisions),
                'recall': np.mean(recalls),
                'f1_score': np.mean(f1_scores),
                'roc_auc': np.mean(roc_aucs),
                'log_loss': np.mean(log_losses),
                'sample_size': len(model_data)
            }

            print(result)
            results.append(result)

        except Exception as e:
            print(f"Error processing window={window}, range_threshold={range_threshold}, lambda={lambda_val[0]}: {e}")

# Convert results to DataFrame for easy analysis
final_results_df_logistic = pd.DataFrame(results)
# Out:
# Error processing window=12, range_threshold=2, lambda=0: division by zero
# {'window': 12, 'range_threshold': 2, 'lambda': 0.01, 'accuracy': np.float64(0.4382180009045681), 'precision': np.float64(0.46673433483437876), 'recall': np.float64(0.6192448399456186), 'f1_score': np.float64(0.522823511421807), 'roc_auc': np.float64(0.47558345728534823), 'log_loss': np.float64(0.7183943245512387), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'lambda': 0.03, 'accuracy': np.float64(0.4382180009045681), 'precision': np.float64(0.46673433483437876), 'recall': np.float64(0.6192448399456186), 'f1_score': np.float64(0.522823511421807), 'roc_auc': np.float64(0.4755855187779548), 'log_loss': np.float64(0.7183455499427027), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'lambda': 0.07, 'accuracy': np.float64(0.4382180009045681), 'precision': np.float64(0.46673433483437876), 'recall': np.float64(0.6192448399456186), 'f1_score': np.float64(0.522823511421807), 'roc_auc': np.float64(0.4763278223400581), 'log_loss': np.float64(0.7182490928299317), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'lambda': 0.1, 'accuracy': np.float64(0.4382180009045681), 'precision': np.float64(0.46673433483437876), 'recall': np.float64(0.6192448399456186), 'f1_score': np.float64(0.522823511421807), 'roc_auc': np.float64(0.4759570972529816), 'log_loss': np.float64(0.71817768495388), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'lambda': 0.3, 'accuracy': np.float64(0.4382180009045681), 'precision': np.float64(0.46673433483437876), 'recall': np.float64(0.6192448399456186), 'f1_score': np.float64(0.522823511421807), 'roc_auc': np.float64(0.4768907704780897), 'log_loss': np.float64(0.7177206924758643), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'lambda': 0.7, 'accuracy': np.float64(0.4412483039348711), 'precision': np.float64(0.46876626516819586), 'recall': np.float64(0.6256964528488445), 'f1_score': np.float64(0.5262084798670166), 'roc_auc': np.float64(0.476147757482574), 'log_loss': np.float64(0.716894436163704), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 
 'sample_size': 132}
# {'window': 16, 'range_threshold': 2, 'lambda': 0.3, 'accuracy': np.float64(0.5082621082621083), 'precision': np.float64(0.5194047619047619), 'recall': np.float64(0.5748567119155354), 'f1_score': np.float64(0.5253435354658935), 'roc_auc': np.float64(0.4971192382278355), 'log_loss': np.float64(0.7684069932056182), 'sample_size': 132}
# {'window': 16, 'range_threshold': 2, 'lambda': 0.7, 'accuracy': np.float64(0.5159544159544159), 'precision': np.float64(0.5330411255411256), 'recall': np.float64(0.5748567119155354), 'f1_score': np.float64(0.5297770330028395), 'roc_auc': np.float64(0.501017464184885), 'log_loss': np.float64(0.7514163882595696), 'sample_size': 132}
# {'window': 16, 'range_threshold': 2, 'lambda': 1, 'accuracy': np.float64(0.5085470085470085), 'precision': np.float64(0.5295779220779221), 'recall': np.float64(0.5748567119155354), 'f1_score': np.float64(0.5265512265512264), 'roc_auc': np.float64(0.5080178896015999), 'log_loss': np.float64(0.7438833661757781), 'sample_size': 132}
# {'window': 16, 'range_threshold': 2, 'lambda': 3, 'accuracy': np.float64(0.5307692307692308), 'precision': np.float64(0.5452864782276546), 'recall': np.float64(0.6115233785822022), 'f1_score': np.float64(0.5493960541374334), 'roc_auc': np.float64(0.5143436704070188), 'log_loss': np.float64(0.7233331441774514), 'sample_size': 132}
# {'window': 16, 'range_threshold': 2, 'lambda': 7, 'accuracy': np.float64(0.5381766381766382), 'precision': np.float64(0.5511688311688312), 'recall': np.float64(0.6281900452488688), 'f1_score': np.float64(0.5590512265512266), 'roc_auc': np.float64(0.5128123912286808), 'log_loss': np.float64(0.7118627614233226), 'sample_size': 132}
# {'window': 16, 'range_threshold': 2, 'lambda': 10, 'accuracy': np.float64(0.5381766381766382), 'precision': np.float64(0.5511688311688312), 'recall': np.float64(0.6281900452488688), 'f1_score': np.float64(0.5590512265512266), 'roc_auc': np.float64(0.5126022243216812), 'log_loss': np.float64(0.7080473834453154), 'sample_size': 132}
# {'window': 16, 'range_threshold': 2, 'lambda': 30, 'accuracy': np.float64(0.5304843304843304), 'precision': np.float64(0.5477871148459383), 'recall': np.float64(0.5964253393665159), 'f1_score': np.float64(0.5438620539844121), 'roc_auc': np.float64(0.5213884883341897), 'log_loss': np.float64(0.6994605293854075), 'sample_size': 132}
# {'window': 16, 'range_threshold': 2, 'lambda': 70, 'accuracy': np.float64(0.5230769230769231), 'precision': np.float64(0.545079365079365), 'recall': np.float64(0.5833785822021116), 'f1_score': np.float64(0.534294737520544), 'roc_auc': np.float64(0.5156951695865724), 'log_loss': np.float64(0.6958592025028634), 'sample_size': 132}
# {'window': 16, 'range_threshold': 2, 'lambda': 100, 'accuracy': np.float64(0.5153846153846153), 'precision': np.float64(0.5341702741702742), 'recall': np.float64(0.5833785822021116), 'f1_score': np.float64(0.5295516545165915), 'roc_auc': np.float64(0.5108515240415693), 'log_loss': np.float64(0.6949744229938102), 'sample_size': 132}
# Error processing window=20, range_threshold=2, lambda=0: division by zero
# {'window': 20, 'range_threshold': 2, 'lambda': 0.01, 'accuracy': np.float64(0.49428571428571433), 'precision': np.float64(0.4883333333333334), 'recall': np.float64(0.5730158730158731), 'f1_score': np.float64(0.5148187759952465), 'roc_auc': np.float64(0.43201247165532874), 'log_loss': np.float64(0.8159840643497962), 'sample_size': 71}
# {'window': 20, 'range_threshold': 2, 'lambda': 0.03, 'accuracy': np.float64(0.49428571428571433), 'precision': np.float64(0.4883333333333334), 'recall': np.float64(0.5730158730158731), 'f1_score': np.float64(0.5148187759952465), 'roc_auc': np.float64(0.43617913832199556), 'log_loss': np.float64(0.8134897047492249), 'sample_size': 71}
# {'window': 20, 'range_threshold': 2, 
 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'lambda': 0.03, 'accuracy': np.float64(0.425), 'precision': np.float64(0.4523809523809524), 'recall': np.float64(0.4666666666666666), 'f1_score': np.float64(0.39222222222222225), 'roc_auc': np.float64(0.5096825396825396), 'log_loss': np.float64(0.992442535555548), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'lambda': 0.07, 'accuracy': np.float64(0.425), 'precision': np.float64(0.4523809523809524), 'recall': np.float64(0.4666666666666666), 'f1_score': np.float64(0.39222222222222225), 'roc_auc': np.float64(0.5096825396825396), 'log_loss': np.float64(0.9398564221297236), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'lambda': 0.1, 'accuracy': np.float64(0.425), 'precision': np.float64(0.4523809523809524), 'recall': np.float64(0.4666666666666666), 'f1_score': np.float64(0.39222222222222225), 'roc_auc': np.float64(0.4953968253968254), 'log_loss': np.float64(0.9140734563815947), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'lambda': 0.3, 'accuracy': np.float64(0.46944444444444444), 'precision': np.float64(0.49285714285714277), 'recall': np.float64(0.6), 'f1_score': np.float64(0.4622222222222222), 'roc_auc': np.float64(0.5298412698412699), 'log_loss': np.float64(0.839158574654007), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'lambda': 0.7, 'accuracy': np.float64(0.4916666666666666), 'precision': np.float64(0.5928571428571427), 'recall': np.float64(0.6333333333333334), 'f1_score': np.float64(0.5122222222222221), 'roc_auc': np.float64(0.5466666666666666), 'log_loss': np.float64(0.7985043809317236), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'lambda': 1, 'accuracy': np.float64(0.4916666666666666), 'precision': np.float64(0.5928571428571427), 'recall': np.float64(0.6333333333333334), 'f1_score': np.float64(0.5122222222222221), 'roc_auc': np.float64(0.5744444444444444), 'log_loss': np.float64(0.7851528420923296), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'lambda': 3, 'accuracy': np.float64(0.4916666666666666), 'precision': np.float64(0.5928571428571427), 'recall': np.float64(0.6666666666666666), 'f1_score': np.float64(0.5422222222222223), 'roc_auc': np.float64(0.5766666666666665), 'log_loss': np.float64(0.7490574506769823), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'lambda': 7, 'accuracy': np.float64(0.4916666666666666), 'precision': np.float64(0.5928571428571427), 'recall': np.float64(0.6666666666666666), 'f1_score': np.float64(0.5422222222222223), 'roc_auc': np.float64(0.5877777777777778), 'log_loss': np.float64(0.7249080336498903), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'lambda': 10, 'accuracy': np.float64(0.46944444444444444), 'precision': np.float64(0.5761904761904761), 'recall': np.float64(0.6333333333333333), 'f1_score': np.float64(0.5111111111111111), 'roc_auc': np.float64(0.5877777777777778), 'log_loss': np.float64(0.7166437229292658), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'lambda': 30, 'accuracy': np.float64(0.46944444444444444), 'precision': np.float64(0.5761904761904761), 'recall': np.float64(0.6333333333333333), 'f1_score': np.float64(0.5111111111111111), 'roc_auc': np.float64(0.6131746031746032), 'log_loss': np.float64(0.7005270898048221), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'lambda': 70, 'accuracy': np.float64(0.46944444444444444), 'precision': np.float64(0.5761904761904761), 'recall': np.float64(0.6333333333333333), 'f1_score': np.float64(0.5111111111111111), 'roc_auc': np.float64(0.6131746031746032), 'log_loss': np.float64(0.6957314144638366), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'lambda': 100, 'accuracy': np.float64(0.46944444444444444), 'precision': np.float64(0.5761904761904761), 'recall': np.float64(0.6333333333333333), 'f1_score': np.float64(0.5111111111111111), 'roc_auc': np.float64(0.6274603174603175), 'log_loss': np.float64(0.6947933071973786), 'sample_size': 43}
# Error processing window=28, range_threshold=2, lambda=0: division by zero
# {'window': 28, 'range_threshold': 2, 'lambda': 0.01, 'accuracy': np.float64(0.3619047619047619), 'precision': np.float64(0.38), 'recall': np.float64(0.45), 'f1_score': np.float64(0.3238095238095238), 'roc_auc': np.float64(0.45166666666666677), 'log_loss': np.float64(2.1255997156275575), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'lambda': 0.03, 'accuracy': np.float64(0.3904761904761905), 'precision': np.float64(0.38), 'recall': np.float64(0.5), 'f1_score': np.float64(0.36190476190476184), 'roc_auc': np.float64(0.4916666666666667), 'log_loss': np.float64(1.9704195838365919), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'lambda': 0.07, 'accuracy': np.float64(0.3619047619047619), 'precision': np.float64(0.32999999999999996), 'recall': np.float64(0.5), 'f1_score': np.float64(0.34047619047619043), 'roc_auc': np.float64(0.515), 'log_loss': np.float64(1.7783783894760616), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'lambda': 0.1, 'accuracy': np.float64(0.3619047619047619), 'precision': np.float64(0.32999999999999996), 'recall': np.float64(0.5), 'f1_score': np.float64(0.34047619047619043), 'roc_auc': np.float64(0.49833333333333335), 'log_loss': np.float64(1.684787743807296), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'lambda': 0.3, 'accuracy': np.float64(0.33333333333333337), 'precision': np.float64(0.3), 'recall': np.float64(0.55), 'f1_score': np.float64(0.3571428571428571), 'roc_auc': np.float64(0.48166666666666663), 'log_loss': np.float64(1.3994897334597545), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'lambda': 0.7, 'accuracy': np.float64(0.27142857142857146), 'precision': np.float64(0.2733333333333333), 'recall': np.float64(0.55), 'f1_score': np.float64(0.3365079365079365), 'roc_auc': np.float64(0.44833333333333336), 'log_loss': np.float64(1.217301034804339), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'lambda': 1, 'accuracy': np.float64(0.27142857142857146), 'precision': np.float64(0.2733333333333333), 'recall': np.float64(0.55), 'f1_score': np.float64(0.3365079365079365), 'roc_auc': np.float64(0.43166666666666664), 'log_loss': np.float64(1.150832762419725), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'lambda': 3, 'accuracy': np.float64(0.24285714285714283), 'precision': np.float64(0.2533333333333333), 'recall': np.float64(0.5), 'f1_score': np.float64(0.30317460317460315), 'roc_auc': np.float64(0.39166666666666666), 'log_loss': np.float64(0.9699472606705835), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'lambda': 7, 'accuracy': np.float64(0.30476190476190473), 'precision': np.float64(0.2833333333333333), 'recall': np.float64(0.55), 'f1_score': np.float64(0.3438095238095238), 'roc_auc': np.float64(0.3583333333333333), 'log_loss': np.float64(0.8550244604647708), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'lambda': 10, 'accuracy': np.float64(0.30476190476190473), 'precision': np.float64(0.2833333333333333), 'recall': np.float64(0.55), 'f1_score': np.float64(0.3438095238095238), 'roc_auc': np.float64(0.3583333333333333), 'log_loss': np.float64(0.8163700183805211), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'lambda': 30, 'accuracy': np.float64(0.3380952380952381), 'precision': np.float64(0.29), 'recall': np.float64(0.55), 'f1_score': np.float64(0.35333333333333333), 'roc_auc': np.float64(0.3983333333333333), 'log_loss': np.float64(0.7394628209162027), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'lambda': 70, 'accuracy': np.float64(0.3380952380952381), 'precision': np.float64(0.29), 'recall': np.float64(0.55), 'f1_score': np.float64(0.35333333333333333), 'roc_auc': np.float64(0.45499999999999996), 'log_loss': np.float64(0.7132809913311247), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'lambda': 100, 'accuracy': np.float64(0.3380952380952381), 'precision': np.float64(0.29), 'recall': np.float64(0.55), 'f1_score': np.float64(0.35333333333333333), 'roc_auc': np.float64(0.45499999999999996), 'log_loss': np.float64(0.7072264479755137), 'sample_size': 32}
# Error processing window=32, range_threshold=2, lambda=0: division by zero
# {'window': 32, 'range_threshold': 2, 'lambda': 0.01, 'accuracy': np.float64(0.3), 'precision': np.float64(0.11666666666666665), 'recall': np.float64(0.4), 'f1_score': np.float64(0.18), 'roc_auc': np.float64(0.3), 'log_loss': np.float64(1.7555035215981338), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'lambda': 0.03, 'accuracy': np.float64(0.35), 'precision': np.float64(0.13333333333333333), 'recall': np.float64(0.4), 'f1_score': np.float64(0.2), 'roc_auc': np.float64(0.3), 'log_loss': np.float64(1.3709339183536078), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'lambda': 0.07, 'accuracy': np.float64(0.4), 'precision': np.float64(0.13333333333333333), 'recall': np.float64(0.4), 'f1_score': np.float64(0.2), 'roc_auc': np.float64(0.4666666666666667), 'log_loss': np.float64(1.161997235895447), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'lambda': 0.1, 'accuracy': np.float64(0.45), 'precision': np.float64(0.13333333333333333), 'recall': np.float64(0.4), 'f1_score': np.float64(0.2), 'roc_auc': np.float64(0.4666666666666667), 'log_loss': np.float64(1.0946185422349184), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'lambda': 0.3, 'accuracy': np.float64(0.35), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.4), 'log_loss': np.float64(0.937790581823322), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'lambda': 0.7, 'accuracy': np.float64(0.4), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.4), 'log_loss': np.float64(0.8517036326556255), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'lambda': 1, 'accuracy': np.float64(0.4), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.4), 'log_loss': np.float64(0.8224362439950224), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'lambda': 3, 'accuracy': np.float64(0.35), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.4666666666666667), 'log_loss': np.float64(0.757144758055207), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'lambda': 7, 'accuracy': np.float64(0.4), 'precision': np.float64(0.1), 'recall': np.float64(0.1), 'f1_score': np.float64(0.1), 'roc_auc': np.float64(0.4666666666666667), 'log_loss': np.float64(0.7292782309321041), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'lambda': 10, 'accuracy': np.float64(0.4), 'precision': np.float64(0.1), 'recall': np.float64(0.1), 'f1_score': np.float64(0.1), 'roc_auc': np.float64(0.4666666666666667), 'log_loss': np.float64(0.7214586731700324), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'lambda': 30, 'accuracy': np.float64(0.4), 'precision': np.float64(0.1), 'recall': np.float64(0.1), 'f1_score': np.float64(0.1), 'roc_auc': np.float64(0.4), 'log_loss': np.float64(0.7055825544336101), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'lambda': 70, 'accuracy': np.float64(0.4), 'precision': np.float64(0.1), 'recall': np.float64(0.1), 'f1_score': np.float64(0.1), 'roc_auc': np.float64(0.4), 'log_loss': np.float64(0.699114396648778), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'lambda': 100, 'accuracy': np.float64(0.4), 'precision': np.float64(0.1), 'recall': np.float64(0.1), 'f1_score': np.float64(0.1), 'roc_auc': np.float64(0.4), 'log_loss': np.float64(0.6974411391865718), 'sample_size': 20}
# Error processing window=36, range_threshold=2, lambda=0: division by zero
# Error processing window=36, range_threshold=2, lambda=0.01: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, lambda=0.03: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, lambda=0.07: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, lambda=0.1: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, lambda=0.3: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, lambda=0.7: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, lambda=1: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, lambda=3: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, lambda=7: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, lambda=10: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, lambda=30: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, lambda=70: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, lambda=100: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, lambda=0: division by zero
# Error processing window=40, range_threshold=2, lambda=0.01: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, lambda=0.03: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, lambda=0.07: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, lambda=0.1: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, lambda=0.3: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, lambda=0.7: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, lambda=1: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, lambda=3: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, lambda=7: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, lambda=10: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, lambda=30: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, lambda=70: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, lambda=100: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, lambda=0: division by zero
# Error processing window=44, range_threshold=2, lambda=0.01: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, lambda=0.03: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, lambda=0.07: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, lambda=0.1: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, lambda=0.3: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, lambda=0.7: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, lambda=1: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, lambda=3: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, lambda=7: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, lambda=10: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, lambda=30: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, lambda=70: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, lambda=100: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=12, range_threshold=3, lambda=0: division by zero
# {'window': 12, 'range_threshold': 3, 'lambda': 0.01, 'accuracy': np.float64(0.4891385767790262), 'precision': np.float64(0.49848572333848234), 'recall': np.float64(0.5462694482232127), 'f1_score': np.float64(0.5127946911657795), 'roc_auc': np.float64(0.48020806479014666), 'log_loss': np.float64(0.699107698824074), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'lambda': 0.03, 'accuracy': np.float64(0.4891385767790262), 'precision': np.float64(0.49848572333848234), 'recall': np.float64(0.5462694482232127), 'f1_score': np.float64(0.5127946911657795), 'roc_auc': np.float64(0.4801741095344865), 'log_loss': np.float64(0.6991054786744721), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'lambda': 0.07, 'accuracy': np.float64(0.4891385767790262), 'precision': np.float64(0.49848572333848234), 'recall': np.float64(0.5462694482232127), 'f1_score': np.float64(0.5127946911657795), 'roc_auc': np.float64(0.4801404167985092), 'log_loss': np.float64(0.6991010498137527), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'lambda': 0.1, 'accuracy': np.float64(0.4891385767790262), 'precision': np.float64(0.49848572333848234), 'recall': np.float64(0.5462694482232127), 'f1_score': np.float64(0.5127946911657795), 'roc_auc': np.float64(0.48015162752009805), 'log_loss': np.float64(0.6990977381322164), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'lambda': 0.3, 'accuracy': np.float64(0.4868913857677903), 'precision': np.float64(0.4968014087931028), 'recall': np.float64(0.5462694482232127), 'f1_score': np.float64(0.5117220460589135), 'roc_auc': np.float64(0.4802199910213497), 'log_loss': np.float64(0.6990758756224061), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'lambda': 0.7, 'accuracy': np.float64(0.48539325842696635), 'precision': np.float64(0.4955111448871909), 'recall': np.float64(0.5447427306659607), 'f1_score': np.float64(0.5103049238194292), 'roc_auc': np.float64(0.47994769272959603), 'log_loss': np.float64(0.6990332499337475), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'lambda': 1, 'accuracy': np.float64(0.48539325842696635), 'precision': np.float64(0.4955111448871909), 'recall': np.float64(0.5447427306659607), 'f1_score': np.float64(0.5103049238194292), 'roc_auc': np.float64(0.4799589397277496), 'log_loss': np.float64(0.6990021675010445), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'lambda': 3, 'accuracy': np.float64(0.4861423220973783), 'precision': np.float64(0.4966924163648542), 'recall': np.float64(0.5447427306659607), 'f1_score': np.float64(0.5106611875841655), 'roc_auc': np.float64(0.47991122152751925), 'log_loss': np.float64(0.6988127158003065), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 
 'sample_size': 316}
# {'window': 20, 'range_threshold': 3, 'lambda': 0.3, 'accuracy': np.float64(0.4334325396825397), 'precision': np.float64(0.42817653276955603), 'recall': np.float64(0.3788702784670527), 'f1_score': np.float64(0.37665924041525334), 'roc_auc': np.float64(0.446962597701845), 'log_loss': np.float64(0.7078156027846068), 'sample_size': 316}
# {'window': 20, 'range_threshold': 3, 'lambda': 0.7, 'accuracy': np.float64(0.43660714285714286), 'precision': np.float64(0.4358688404618637), 'recall': np.float64(0.3788702784670527), 'f1_score': np.float64(0.3778020975581105), 'roc_auc': np.float64(0.4482015242991945), 'log_loss': np.float64(0.707188360773151), 'sample_size': 316}
# {'window': 20, 'range_threshold': 3, 'lambda': 1, 'accuracy': np.float64(0.43660714285714286), 'precision': np.float64(0.4358688404618637), 'recall': np.float64(0.3788702784670527), 'f1_score': np.float64(0.3778020975581105), 'roc_auc': np.float64(0.448816798727193), 'log_loss': np.float64(0.70679148629167), 'sample_size': 316}
# {'window': 20, 'range_threshold': 3, 'lambda': 3, 'accuracy': np.float64(0.4334325396825397), 'precision': np.float64(0.42074675324675326), 'recall': np.float64(0.36775916735594155), 'f1_score': np.float64(0.36449120428313164), 'roc_auc': np.float64(0.4527970944413597), 'log_loss': np.float64(0.7049791222418585), 'sample_size': 316}
# {'window': 20, 'range_threshold': 3, 'lambda': 7, 'accuracy': np.float64(0.44290674603174607), 'precision': np.float64(0.4297679232642385), 'recall': np.float64(0.38190308795147504), 'f1_score': np.float64(0.3751547635717013), 'roc_auc': np.float64(0.45546118420222365), 'log_loss': np.float64(0.7029620361786617), 'sample_size': 316}
# {'window': 20, 'range_threshold': 3, 'lambda': 10, 'accuracy': np.float64(0.44608134920634923), 'precision': np.float64(0.4354822089785242), 'recall': np.float64(0.38190308795147504), 'f1_score': np.float64(0.37626484682794553), 'roc_auc': np.float64(0.45550430622115207), 'log_loss': np.float64(0.7019622481974339), 'sample_size': 316}
# {'window': 20, 'range_threshold': 3, 'lambda': 30, 'accuracy': np.float64(0.4619047619047619), 'precision': np.float64(0.46585858585858586), 'recall': np.float64(0.39584539564378274), 'f1_score': np.float64(0.39192575266280505), 'roc_auc': np.float64(0.4627917977380343), 'log_loss': np.float64(0.6986257996745883), 'sample_size': 316}
# {'window': 20, 'range_threshold': 3, 'lambda': 70, 'accuracy': np.float64(0.45555555555555555), 'precision': np.float64(0.4565087668313475), 'recall': np.float64(0.4087486214502344), 'f1_score': np.float64(0.3950323104283333), 'roc_auc': np.float64(0.46347405019), 'log_loss': np.float64(0.6963787683658924), 'sample_size': 316}
# {'window': 20, 'range_threshold': 3, 'lambda': 100, 'accuracy': np.float64(0.4554563492063492), 'precision': np.float64(0.45258008721883397), 'recall': np.float64(0.4281034601599118), 'f1_score': np.float64(0.4045893719806763), 'roc_auc': np.float64(0.46551912120908534), 'log_loss': np.float64(0.6956385479237778), 'sample_size': 316}
# Error processing window=24, range_threshold=3, lambda=0: division by zero
# {'window': 24, 'range_threshold': 3, 'lambda': 0.01, 'accuracy': np.float64(0.47027027027027035), 'precision': np.float64(0.4931652661064426), 'recall': np.float64(0.6434083202659053), 'f1_score': np.float64(0.5447244804467649), 'roc_auc': np.float64(0.46336401386710974), 'log_loss': np.float64(0.7239927214865374), 'sample_size': 185}
# {'window': 24, 'range_threshold': 3, 'lambda': 0.03, 'accuracy': np.float64(0.47027027027027035), 'precision': np.float64(0.4931652661064426), 'recall': np.float64(0.6434083202659053), 'f1_score': np.float64(0.5447244804467649), 'roc_auc': np.float64(0.4639700744731704), 'log_loss': np.float64(0.723906794058908), 'sample_size': 185}
# {'window': 24, 'range_threshold': 3, 'lambda': 0.07, 'accuracy': np.float64(0.47027027027027035), 'precision': np.float64(0.4931652661064426), 'recall': np.float64(0.6434083202659053), 'f1_score': np.float64(0.5447244804467649), 'roc_auc': np.float64(0.46280048382989564), 'log_loss': np.float64(0.7237436941323534), 'sample_size': 185}
# {'window': 24, 'range_threshold': 3, 'lambda': 0.1, 'accuracy': np.float64(0.4648648648648649), 'precision': np.float64(0.48745098039215684), 'recall': np.float64(0.6434083202659053), 'f1_score': np.float64(0.5420666731377948), 'roc_auc': np.float64(0.4639735144456506), 'log_loss': np.float64(0.7236283678123477), 'sample_size': 185}
# {'window': 24, 'range_threshold': 3, 'lambda': 0.3, 'accuracy': np.float64(0.47027027027027035), 'precision': np.float64(0.49089184060721064), 'recall': np.float64(0.6551730261482583), 'f1_score': np.float64(0.5479177369675821), 'roc_auc': np.float64(0.45700256657687), 'log_loss': np.float64(0.722976339803857), 'sample_size': 185}
# {'window': 24, 'range_threshold': 3, 'lambda': 0.7, 'accuracy': np.float64(0.4648648648648649), 'precision': np.float64(0.4910997510318393), 'recall': np.float64(0.634120394569311), 'f1_score': np.float64(0.5394779881365247), 'roc_auc': np.float64(0.4564530421418967), 'log_loss': np.float64(0.7220197532575868), 'sample_size': 185}
# {'window': 24, 'range_threshold': 3, 'lambda': 1, 'accuracy': np.float64(0.4486486486486487), 'precision': np.float64(0.47844241639308055), 'recall': np.float64(0.6159385763874928), 'f1_score': np.float64(0.5222636059592581), 'roc_auc': np.float64(0.4516254428406131), 'log_loss': np.float64(0.7214525220659811), 'sample_size': 185}
# {'window': 24, 'range_threshold': 3, 'lambda': 3, 'accuracy': np.float64(0.4378378378378378), 'precision': np.float64(0.470271164021164), 'recall': np.float64(0.6068476672965837), 'f1_score': np.float64(0.5118853250922555), 'roc_auc': np.float64(0.43247024647179444), 'log_loss': np.float64(0.7187301195512815), 'sample_size': 185}
# ...
# {'window': 32, 'range_threshold': 10, 'lambda': 0.7, 'accuracy': np.float64(0.5346772591857001), 'precision': np.float64(0.5386888363325213), 'recall': np.float64(0.7701850733153935), 'f1_score': np.float64(0.6331660834142558), 'roc_auc': np.float64(0.5246435422265221), 'log_loss': np.float64(0.6928376141668469), 'sample_size': 1326}
# {'window': 32, 'range_threshold': 10, 'lambda': 1, 'accuracy': np.float64(0.5346772591857001), 'precision': np.float64(0.5386888363325213), 'recall': np.float64(0.7701850733153935), 'f1_score': np.float64(0.6331660834142558), 'roc_auc': np.float64(0.5245642302315086), 'log_loss': np.float64(0.692830430061075), 'sample_size': 1326}
# {'window': 32, 'range_threshold': 10, 'lambda': 3, 'accuracy': np.float64(0.5339225422045681), 'precision': np.float64(0.538217480277409), 'recall': np.float64(0.7687766226111681), 'f1_score': np.float64(0.6323526921311572), 'roc_auc': np.float64(0.524563465689045), 'log_loss': np.float64(0.6927846120575054), 'sample_size': 1326}
# {'window': 32, 'range_threshold': 10, 'lambda': 7, 'accuracy': np.float64(0.533167825223436), 'precision': np.float64(0.5376736079061255), 'recall': np.float64(0.7687766226111681), 'f1_score': np.float64(0.6319861424113059), 'roc_auc': np.float64(0.5245174049710731), 'log_loss': np.float64(0.6927021427931124), 'sample_size': 1326}
# {'window': 32, 'range_threshold': 10, 'lambda': 10, 'accuracy': np.float64(0.533167825223436), 'precision': np.float64(0.5376736079061255), 'recall': np.float64(0.7687766226111681), 'f1_score': np.float64(0.6319861424113059), 'roc_auc': np.float64(0.5248135807452676), 'log_loss': np.float64(0.6926467418991995), 'sample_size': 1326}
# {'window': 32, 'range_threshold': 10, 'lambda': 30, 'accuracy': np.float64(0.5309008369981558), 'precision': np.float64(0.5361240973095505), 'recall': np.float64(0.7673681719069427), 'f1_score': np.float64(0.6304530208047308), 'roc_auc': np.float64(0.5259077868902196), 'log_loss': np.float64(0.692365247196274), 'sample_size': 1326}
# {'window': 32, 'range_threshold': 10, 'lambda': 70, 'accuracy': np.float64(0.5354234643211804), 'precision': np.float64(0.5394819135177971), 'recall': np.float64(0.768570487121753), 'f1_score': np.float64(0.6331733339855946), 'roc_auc': np.float64(0.5274008932629923), 'log_loss': np.float64(0.6920364885877082), 'sample_size': 1326}
# {'window': 32, 'range_threshold': 10, 'lambda': 100, 'accuracy': np.float64(0.5384423322457086), 'precision': np.float64(0.5416669529441813), 'recall': np.float64(0.768540088905115), 'f1_score': np.float64(0.6346219672307827), 'roc_auc': np.float64(0.5283477256877168), 'log_loss': np.float64(0.6918933779576086), 'sample_size': 1326}
# Error processing window=36, range_threshold=10, lambda=0: division by zero
# {'window': 36, 'range_threshold': 10, 'lambda': 0.01, 'accuracy': np.float64(0.4954586589880708), 'precision': np.float64(0.5113239757880146), 'recall': np.float64(0.5949750929844811), 'f1_score': np.float64(0.5442045709223086), 'roc_auc': np.float64(0.5087260952523456), 'log_loss': np.float64(0.6978733299417224), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'lambda': 0.03, 'accuracy': np.float64(0.4954586589880708), 'precision': np.float64(0.5113239757880146), 'recall': np.float64(0.5949750929844811), 'f1_score': np.float64(0.5442045709223086), 'roc_auc': np.float64(0.5087427619190124), 'log_loss': np.float64(0.6978717893640446), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'lambda': 0.07, 'accuracy': np.float64(0.4945495680789798), 'precision': np.float64(0.510564810869425), 'recall': np.float64(0.5949750929844811), 'f1_score': np.float64(0.5437425086654993), 'roc_auc': np.float64(0.5087427619190124), 'log_loss': np.float64(0.6978687133671252), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'lambda': 0.1, 'accuracy': np.float64(0.4945495680789798), 'precision': np.float64(0.510564810869425), 'recall': np.float64(0.5949750929844811), 'f1_score': np.float64(0.5437425086654993), 'roc_auc': np.float64(0.5087095608608113), 'log_loss': np.float64(0.6978664108663013), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'lambda': 0.3, 'accuracy': np.float64(0.4945495680789798), 'precision': np.float64(0.510564810869425), 'recall': np.float64(0.5949750929844811), 'f1_score': np.float64(0.5437425086654993), 'roc_auc': np.float64(0.5087756236627436), 'log_loss': np.float64(0.6978511582760228), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 
 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'lambda': 100, 'accuracy': np.float64(0.4876344086021505), 'precision': np.float64(0.5010487560569504), 'recall': np.float64(0.5228345164421795), 'f1_score': np.float64(0.4938372006177011), 'roc_auc': np.float64(0.49414896395581864), 'log_loss': np.float64(0.6999718268690633), 'sample_size': 777}

# %%
# final_results_df_logistic = pd.read_csv('final_results_df_logistic.csv')

# %%
print(final_results_df_logistic.shape)
precision_logistic = final_results_df_logistic[final_results_df_logistic['sample_size'] >= 300].sort_values(by='precision', ascending=False)
precision_logistic.head()
# Out:
# (1014, 10)
#      window  range_threshold  lambda  accuracy  precision    recall  f1_score  \
# 514      36                6    3.00  0.579016   0.589478  0.707787  0.641765
# 513      36                6    1.00  0.575295   0.587610  0.696724  0.636177
# 507      36                6    0.01  0.573409   0.585788  0.696724  0.635127
# 508      36                6    0.03  0.573409   0.585788  0.696724  0.635127
# 509      36                6    0.07  0.573409   0.585788  0.696724  0.635127
#
#       roc_auc  log_loss  sample_size
# 514  0.542381  0.699236          532
# 513  0.541360  0.700302          532
# 507  0.541250  0.701006          532
# 508  0.541180  0.700990          532
# 509  0.541030  0.700959          532

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
import itertools
import numpy as np

# New Random Forest hyperparameters
max_depth = [4, 5, 6, 7]
min_samples_split = [5, 10, 15]
min_samples_leaf = [4]

# Generate all combinations of RF hyperparameters
rf_hyperparam_combinations = list(itertools.product(max_depth, min_samples_split, min_samples_leaf))

# Store results
results = []

# Loop through each (range_threshold, window) in model_data_dict
for (range_threshold, window), model_data in model_data_dict.items():
    if model_data.empty:
        print(f"Warning: No data collected for window={window}, range_threshold={range_threshold}")
        continue  # Skip if no data

    # Split into features (X) and target (y)
    X = model_data[['average_volume_after_breakout', 'average_volume', 
                    'breakout_over_consolidation_volume_ratio', 'std_dev', 
                    'breakout_relative_size', 'breakout_after_12pm']]
    y = model_data['worked?']

    # Loop over each combination of Random Forest hyperparameters
    for depth, split, leaf in rf_hyperparam_combinations:
        try:
            cv = KFold(n_splits=5, shuffle=True, random_state=42)

            # Lists for storing fold metrics
            accuracies, precisions, recalls, f1_scores, roc_aucs, log_losses = [], [], [], [], [], []

            # 5-fold cross-validation
            for train_index, test_index in cv.split(X):
                X_train_cv, X_test_cv = X.iloc[train_index], X.iloc[test_index]
                y_train_cv, y_test_cv = y.iloc[train_index], y.iloc[test_index]

                # Scale features to avoid data leakage
                scaler = StandardScaler()
                X_train_scaled = scaler.fit_transform(X_train_cv)
                X_test_scaled = scaler.transform(X_test_cv)

                # Train RandomForestClassifier with current hyperparameters
                rf = RandomForestClassifier(max_depth=depth, 
                                            min_samples_split=split, 
                                            min_samples_leaf=leaf,
                                            random_state=42)
                rf.fit(X_train_scaled, y_train_cv)

                # Evaluate the model on the testing fold
                y_pred = rf.predict(X_test_scaled)
                y_prob = rf.predict_proba(X_test_scaled)[:, 1]

                # Compute metrics
                accuracies.append(accuracy_score(y_test_cv, y_pred))
                precisions.append(precision_score(y_test_cv, y_pred))
                recalls.append(recall_score(y_test_cv, y_pred))
                f1_scores.append(f1_score(y_test_cv, y_pred))
                roc_aucs.append(roc_auc_score(y_test_cv, y_prob))
                log_losses.append(log_loss(y_test_cv, y_prob))

            # Store average metrics over folds along with hyperparameters and data info
            result = {
                'window': window,
                'range_threshold': range_threshold,
                'max_depth': depth,
                'min_samples_split': split,
                'accuracy': np.mean(accuracies),
                'precision': np.mean(precisions),
                'recall': np.mean(recalls),
                'f1_score': np.mean(f1_scores),
                'roc_auc': np.mean(roc_aucs),
                'log_loss': np.mean(log_losses),
                'sample_size': len(model_data)
            }
            print(result)
            results.append(result)

        except Exception as e:
            print(f"Error processing window={window}, range_threshold={range_threshold}, "
                  f"max_depth={depth}, min_samples_split={split}, min_samples_leaf={leaf}: {e}")

# Convert results to DataFrame for easy analysis
final_results_df_random_forest = pd.DataFrame(results)
# Out:
# {'window': 12, 'range_threshold': 2, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 4, 'accuracy': np.float64(0.49253731343283585), 'precision': np.float64(0.5124371752278728), 'recall': np.float64(0.5999463248406519), 'f1_score': np.float64(0.541675854617031), 'roc_auc': np.float64(0.5279701622805071), 'log_loss': np.float64(0.6979232183440002), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 4, 'accuracy': np.float64(0.4955676164631388), 'precision': np.float64(0.5162813755574728), 'recall': np.float64(0.6013979377438776), 'f1_score': np.float64(0.5423517264901547), 'roc_auc': np.float64(0.5308992879738152), 'log_loss': np.float64(0.6956764143573332), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0.48950701040253275), 'precision': np.float64(0.5114957264957265), 'recall': np.float64(0.5874461041368717), 'f1_score': np.float64(0.5349902304480532), 'roc_auc': np.float64(0.5247677058911764), 'log_loss': np.float64(0.6972757196213211), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 4, 'accuracy': np.float64(0.48946178199909546), 'precision': np.float64(0.5128688156595134), 'recall': np.float64(0.5518757172872857), 'f1_score': np.float64(0.5200558630136094), 'roc_auc': np.float64(0.5309779690702938), 'log_loss': np.float64(0.7009018852454246), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 4, 'accuracy': np.float64(0.5045228403437358), 'precision': np.float64(0.5273075946760157), 'recall': np.float64(0.5926529477196885), 'f1_score': np.float64(0.5464474922683877), 'roc_auc': np.float64(0.5424170022557119), 'log_loss': np.float64(0.6963636059289098), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0.4743102668475803), 'precision': np.float64(0.5019349784567175), 'recall': np.float64(0.5524543143174956), 'f1_score': np.float64(0.5120929765360975), 'roc_auc': np.float64(0.5380940578270945), 'log_loss': np.float64(0.6989525770491306), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 4, 'accuracy': np.float64(0.5044776119402985), 'precision': np.float64(0.5284719334719334), 'recall': np.float64(0.5539243780567473), 'f1_score': np.float64(0.5315326252822582), 'roc_auc': np.float64(0.5355410654576394), 'log_loss': np.float64(0.7055523361762095), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 4, 'accuracy': np.float64(0.5075531433740389), 'precision': np.float64(0.528735900459153), 'recall': np.float64(0.5640349947913907), 'f1_score': np.float64(0.5380208268187807), 'roc_auc': np.float64(0.5375550713592983), 'log_loss': np.float64(0.702441052396244), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0.5075079149706015), 'precision': np.float64(0.5289799551733456), 'recall': np.float64(0.5715101435457386), 'f1_score': np.float64(0.5397030833650552), 'roc_auc': np.float64(0.5458994112498006), 'log_loss': np.float64(0.6993900172150992), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 4, 'accuracy': np.float64(0.5317503392130257), 'precision': np.float64(0.5571546732837055), 'recall': np.float64(0.5595905503469464), 'f1_score': np.float64(0.5471998012498328), 'roc_auc': np.float64(0.549224277511263), 'log_loss': np.float64(0.7045568336107697), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 4, 'accuracy': np.float64(0.5377657168701945), 'precision': np.float64(0.5596705327193131), 'recall': np.float64(0.5879156734996557), 'f1_score': np.float64(0.5643942311148079), 'roc_auc': np.float64(0.5601526093072255), 'log_loss': np.float64(0.6993942611268353), 'sample_size': 331}
# {'window': 12, 'range_threshold': 2, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0
 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0.2761904761904762), 'precision': np.float64(0.4133333333333333), 'recall': np.float64(0.44000000000000006), 'f1_score': np.float64(0.3126984126984127), 'roc_auc': np.float64(0.38583333333333336), 'log_loss': np.float64(0.7868462636248504), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 4, 'accuracy': np.float64(0.3714285714285714), 'precision': np.float64(0.44666666666666666), 'recall': np.float64(0.48), 'f1_score': np.float64(0.37460317460317455), 'roc_auc': np.float64(0.39), 'log_loss': np.float64(0.7893901018284224), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 4, 'accuracy': np.float64(0.3380952380952381), 'precision': np.float64(0.44666666666666666), 'recall': np.float64(0.48), 'f1_score': np.float64(0.37460317460317455), 'roc_auc': np.float64(0.41916666666666663), 'log_loss': np.float64(0.7847741045890941), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0.2761904761904762), 'precision': np.float64(0.4133333333333333), 'recall': np.float64(0.44000000000000006), 'f1_score': np.float64(0.3126984126984127), 'roc_auc': np.float64(0.38583333333333336), 'log_loss': np.float64(0.7868462636248504), 'sample_size': 32}
# {'window': 32, 'range_threshold': 2, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 4, 'accuracy': np.float64(0.55), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.4833333333333334), 'log_loss': np.float64(0.6796037994035204), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 4, 'accuracy': np.float64(0.65), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.5333333333333334), 'log_loss': np.float64(0.6686719680953603), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0.65), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.5), 'log_loss': np.float64(0.6665846644826592), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 4, 'accuracy': np.float64(0.55), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.4833333333333334), 'log_loss': np.float64(0.6796037994035204), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 4, 'accuracy': np.float64(0.65), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.5333333333333334), 'log_loss': np.float64(0.6686719680953603), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0.65), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.5), 'log_loss': np.float64(0.6665846644826592), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 4, 'accuracy': np.float64(0.55), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.4833333333333334), 'log_loss': np.float64(0.6796037994035204), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 4, 'accuracy': np.float64(0.65), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.5333333333333334), 'log_loss': np.float64(0.6686719680953603), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0.65), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.5), 'log_loss': np.float64(0.6665846644826592), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 4, 'accuracy': np.float64(0.55), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.4833333333333334), 'log_loss': np.float64(0.6796037994035204), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 4, 'accuracy': np.float64(0.65), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.5333333333333334), 'log_loss': np.float64(0.6686719680953603), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0.65), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.5), 'log_loss': np.float64(0.6665846644826592), 'sample_size': 20}
# Error processing window=36, range_threshold=2, max_depth=4, min_samples_split=5, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, max_depth=4, min_samples_split=10, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, max_depth=4, min_samples_split=15, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, max_depth=5, min_samples_split=5, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, max_depth=5, min_samples_split=10, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, max_depth=5, min_samples_split=15, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, max_depth=6, min_samples_split=5, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, max_depth=6, min_samples_split=10, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, max_depth=6, min_samples_split=15, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, max_depth=7, min_samples_split=5, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, max_depth=7, min_samples_split=10, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, max_depth=7, min_samples_split=15, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, max_depth=4, min_samples_split=5, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, max_depth=4, min_samples_split=10, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, max_depth=4, min_samples_split=15, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, max_depth=5, min_samples_split=5, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, max_depth=5, min_samples_split=10, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, max_depth=5, min_samples_split=15, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, max_depth=6, min_samples_split=5, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, max_depth=6, min_samples_split=10, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, max_depth=6, min_samples_split=15, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, max_depth=7, min_samples_split=5, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, max_depth=7, min_samples_split=10, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, max_depth=7, min_samples_split=15, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, max_depth=4, min_samples_split=5, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, max_depth=4, min_samples_split=10, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, max_depth=4, min_samples_split=15, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, max_depth=5, min_samples_split=5, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, max_depth=5, min_samples_split=10, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, max_depth=5, min_samples_split=15, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, max_depth=6, min_samples_split=5, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, max_depth=6, min_samples_split=10, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, max_depth=6, min_samples_split=15, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, max_depth=7, min_samples_split=5, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, max_depth=7, min_samples_split=10, min_samples_leaf=4: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2
 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 4, 'accuracy': np.float64(0.45684863523573205), 'precision': np.float64(0.4785637047183172), 'recall': np.float64(0.5205627553290457), 'f1_score': np.float64(0.47955666244719514), 'roc_auc': np.float64(0.4659961632888109), 'log_loss': np.float64(0.7158867441381627), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 4, 'accuracy': np.float64(0.4594044665012407), 'precision': np.float64(0.4798073569050262), 'recall': np.float64(0.5251223961493345), 'f1_score': np.float64(0.48348556909559237), 'roc_auc': np.float64(0.4686790263392437), 'log_loss': np.float64(0.7155865417982394), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0.4594127377998346), 'precision': np.float64(0.4778555967841682), 'recall': np.float64(0.5262667050924241), 'f1_score': np.float64(0.48272876056923575), 'roc_auc': np.float64(0.46135230884752315), 'log_loss': np.float64(0.7156622783058164), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 4, 'accuracy': np.float64(0.4632919768403639), 'precision': np.float64(0.48327176658702403), 'recall': np.float64(0.5114138858552765), 'f1_score': np.float64(0.4833624625329639), 'roc_auc': np.float64(0.4618302938646427), 'log_loss': np.float64(0.7217027793818362), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 4, 'accuracy': np.float64(0.4555748552522746), 'precision': np.float64(0.4747213813434611), 'recall': np.float64(0.5002600715932533), 'f1_score': np.float64(0.47506041677261146), 'roc_auc': np.float64(0.4650017263341707), 'log_loss': np.float64(0.7215991915459398), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0.44911497105045495), 'precision': np.float64(0.46843746624017735), 'recall': np.float64(0.5002667657646727), 'f1_score': np.float64(0.4678675527621561), 'roc_auc': np.float64(0.46344563740371003), 'log_loss': np.float64(0.7204236554559735), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 4, 'accuracy': np.float64(0.46461538461538465), 'precision': np.float64(0.48365891119570303), 'recall': np.float64(0.5094802208469846), 'f1_score': np.float64(0.4852736204013473), 'roc_auc': np.float64(0.46858959259593214), 'log_loss': np.float64(0.7255279789492517), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 4, 'accuracy': np.float64(0.4593796526054591), 'precision': np.float64(0.4792480254471564), 'recall': np.float64(0.5001170974396312), 'f1_score': np.float64(0.4754027651348456), 'roc_auc': np.float64(0.46838774136729067), 'log_loss': np.float64(0.7257689533282641), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0.45812241521918945), 'precision': np.float64(0.48054278515443566), 'recall': np.float64(0.5050893196618533), 'f1_score': np.float64(0.477264781113312), 'roc_auc': np.float64(0.462044876988033), 'log_loss': np.float64(0.7262190757492313), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 4, 'accuracy': np.float64(0.47100909842845323), 'precision': np.float64(0.48937637946584367), 'recall': np.float64(0.5140025785705619), 'f1_score': np.float64(0.48883276692115096), 'roc_auc': np.float64(0.4741712018929993), 'log_loss': np.float64(0.72934329188665), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 4, 'accuracy': np.float64(0.4594127377998346), 'precision': np.float64(0.47971354221658824), 'recall': np.float64(0.5045344416130728), 'f1_score': np.float64(0.47971805060689066), 'roc_auc': np.float64(0.4691296472062715), 'log_loss': np.float64(0.7306698943278478), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 4, 'accuracy': np.float64(0.4684532671629446), 'precision': np.float64(0.48495809982719945), 'recall': np.float64(0.5249707155280509), 'f1_score': np.float64(0.49038086540945713), 'roc_auc': np.float64(0.47074206056176615), 'log_loss': np.float64(0.7289524308320482), 'sample_size': 777}

# %%
# final_results_df_random_forest = pd.read_csv('final_results_df_random_forest.csv')

# %%
print(final_results_df_random_forest.shape)
precision_random_forest = final_results_df_random_forest[final_results_df_random_forest['sample_size'] >= 300].sort_values(by='precision', ascending=False)
precision_random_forest.head()
# Out:
# (936, 11)
#      window  range_threshold  max_depth  min_samples_split  accuracy  \
# 478      36                6          7                 10  0.552724
# 477      36                6          7                  5  0.547117
# 238      28                4          7                 10  0.567205
# 472      36                6          5                 10  0.550838
# 237      28                4          7                  5  0.567246
#
#      precision    recall  f1_score   roc_auc  log_loss  sample_size
# 478   0.573691  0.668879  0.615313  0.561975  0.700831          532
# 477   0.571303  0.651149  0.606163  0.562599  0.700381          532
# 238   0.570325  0.599142  0.581926  0.599938  0.698125          349
# 472   0.569517  0.697931  0.624908  0.558882  0.697460          532
# 237   0.569249  0.609567  0.586662  0.590764  0.700710          349

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

n_neighbors = [3, 5, 7, 9, 11, 13, 15, 17, 19]  # Number of neighbors to use
weights = ['uniform', 'distance']  # Weighting function
metrics = ['euclidean']  # Distance metric

# Generate all combinations of hyperparameters
knn_hyperparam_combinations = list(itertools.product(n_neighbors, weights, metrics))


# Store results
results = []

# Loop through the hyperparameter combinations
for (range_threshold, window), model_data in model_data_dict.items():
    for n_neighbors_val, weight, metric in knn_hyperparam_combinations:
        try:
            # Check if model_data is empty
            if model_data.empty:
                print(f"Warning: No data collected for window={window}, range_threshold={range_threshold}")
                continue  # Skip this iteration if no data

            # Split into features (X) and target (y)
            X = model_data[['average_volume_after_breakout', 'average_volume', 'breakout_over_consolidation_volume_ratio',
                            'std_dev', 'breakout_relative_size', 'breakout_after_12pm']]
            y = model_data['worked?']

            cv = KFold(n_splits=5, shuffle=True, random_state=42)

            accuracies, precisions, recalls, f1_scores, roc_aucs, log_losses = [], [], [], [], [], []

            # 5-fold cross-validation
            for train_index, test_index in cv.split(X):
                X_train_cv, X_test_cv = X.iloc[train_index], X.iloc[test_index]
                y_train_cv, y_test_cv = y.iloc[train_index], y.iloc[test_index]

                # Scale the features
                scaler = StandardScaler()
                X_train_scaled = scaler.fit_transform(X_train_cv)
                X_test_scaled = scaler.transform(X_test_cv)

                # Train k-NN Classifier
                knn = KNeighborsClassifier(n_neighbors=n_neighbors_val, weights=weight, metric=metric)
                knn.fit(X_train_scaled, y_train_cv)

                # Evaluate the model on the testing fold
                y_pred = knn.predict(X_test_scaled)
                y_prob = knn.predict_proba(X_test_scaled)[:, 1]

                acc = accuracy_score(y_test_cv, y_pred)
                prec = precision_score(y_test_cv, y_pred)
                rec = recall_score(y_test_cv, y_pred)
                f1_val = f1_score(y_test_cv, y_pred)
                roc_val = roc_auc_score(y_test_cv, y_prob)
                ll = log_loss(y_test_cv, y_prob)

                # Calculate evaluation metrics
                accuracies.append(acc)
                precisions.append(prec)
                recalls.append(rec)
                f1_scores.append(f1_val)
                roc_aucs.append(roc_val)
                log_losses.append(ll)

            result = {
                'window': window,
                'range_threshold': range_threshold,
                'n_neighbors': n_neighbors_val,
                'accuracy': np.mean(accuracies),
                'precision': np.mean(precisions),
                'recall': np.mean(recalls),
                'f1_score': np.mean(f1_scores),
                'roc_auc': np.mean(roc_aucs),
                'log_loss': np.mean(log_losses),
                'sample_size': len(model_data)
            }

            print(result)
            results.append(result)

        except Exception as e:
            print(f"Error processing window={window}, range_threshold={range_threshold}, n_neighbors={n_neighbors_val}, weights={weight}, metric={metric}: {e}")

# Convert results to DataFrame for easy analysis
final_results_df_knn = pd.DataFrame(results)
# Out:
# {'window': 12, 'range_threshold': 2, 'n_neighbors':
 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'n_neighbors': 7, 'accuracy': np.float64(0.5888888888888889), 'precision': np.float64(0.6300000000000001), 'recall': np.float64(0.7), 'f1_score': np.float64(0.6148629148629149), 'roc_auc': np.float64(0.5733333333333334), 'log_loss': np.float64(0.8121817158324346), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'n_neighbors': 9, 'accuracy': np.float64(0.5638888888888889), 'precision': np.float64(0.6000000000000001), 'recall': np.float64(0.7), 'f1_score': np.float64(0.5934343434343434), 'roc_auc': np.float64(0.5987301587301588), 'log_loss': np.float64(0.7216994706838626), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'n_neighbors': 9, 'accuracy': np.float64(0.611111111111111), 'precision': np.float64(0.6433333333333333), 'recall': np.float64(0.7), 'f1_score': np.float64(0.6291486291486291), 'roc_auc': np.float64(0.5968253968253968), 'log_loss': np.float64(0.765810569975986), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'n_neighbors': 11, 'accuracy': np.float64(0.5166666666666666), 'precision': np.float64(0.5800000000000001), 'recall': np.float64(0.7333333333333333), 'f1_score': np.float64(0.5878787878787878), 'roc_auc': np.float64(0.584047619047619), 'log_loss': np.float64(0.7179321332593294), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'n_neighbors': 11, 'accuracy': np.float64(0.5194444444444445), 'precision': np.float64(0.5571428571428572), 'recall': np.float64(0.6666666666666667), 'f1_score': np.float64(0.5434343434343434), 'roc_auc': np.float64(0.5536507936507936), 'log_loss': np.float64(0.7537378213027779), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'n_neighbors': 13, 'accuracy': np.float64(0.46944444444444444), 'precision': np.float64(0.5707142857142856), 'recall': np.float64(0.6333333333333333), 'f1_score': np.float64(0.5454545454545454), 'roc_auc': np.float64(0.5861904761904763), 'log_loss': np.float64(0.7163643633898081), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'n_neighbors': 13, 'accuracy': np.float64(0.5166666666666666), 'precision': np.float64(0.5704761904761904), 'recall': np.float64(0.7), 'f1_score': np.float64(0.5656565656565656), 'roc_auc': np.float64(0.5606349206349206), 'log_loss': np.float64(0.7456924123181692), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'n_neighbors': 15, 'accuracy': np.float64(0.43888888888888894), 'precision': np.float64(0.5323015873015873), 'recall': np.float64(0.7666666666666667), 'f1_score': np.float64(0.5647552447552447), 'roc_auc': np.float64(0.4935714285714286), 'log_loss': np.float64(0.7373153399216675), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'n_neighbors': 15, 'accuracy': np.float64(0.4444444444444445), 'precision': np.float64(0.5257142857142857), 'recall': np.float64(0.7), 'f1_score': np.float64(0.5381818181818182), 'roc_auc': np.float64(0.5173015873015874), 'log_loss': np.float64(0.7566908501050091), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'n_neighbors': 17, 'accuracy': np.float64(0.43888888888888894), 'precision': np.float64(0.5323015873015873), 'recall': np.float64(0.7666666666666667), 'f1_score': np.float64(0.5647552447552447), 'roc_auc': np.float64(0.5134920634920634), 'log_loss': np.float64(0.7216930412365447), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'n_neighbors': 17, 'accuracy': np.float64(0.39722222222222225), 'precision': np.float64(0.5094444444444444), 'recall': np.float64(0.7), 'f1_score': np.float64(0.52), 'roc_auc': np.float64(0.5519047619047619), 'log_loss': np.float64(0.7397462453039028), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'n_neighbors': 19, 'accuracy': np.float64(0.43888888888888894), 'precision': np.float64(0.6123015873015873), 'recall': np.float64(0.7), 'f1_score': np.float64(0.5128071928071928), 'roc_auc': np.float64(0.4247619047619048), 'log_loss': np.float64(0.7433152167439244), 'sample_size': 43}
# {'window': 24, 'range_threshold': 2, 'n_neighbors': 19, 'accuracy': np.float64(0.39722222222222225), 'precision': np.float64(0.5094444444444444), 'recall': np.float64(0.7), 'f1_score': np.float64(0.52), 'roc_auc': np.float64(0.5206349206349207), 'log_loss': np.float64(0.7519914141707031), 'sample_size': 43}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 3, 'accuracy': np.float64(0.4666666666666667), 'precision': np.float64(0.5233333333333332), 'recall': np.float64(0.62), 'f1_score': np.float64(0.4976190476190476), 'roc_auc': np.float64(0.6275000000000001), 'log_loss': np.float64(3.0546125691471557), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 3, 'accuracy': np.float64(0.5285714285714286), 'precision': np.float64(0.54), 'recall': np.float64(0.71), 'f1_score': np.float64(0.5611111111111111), 'roc_auc': np.float64(0.6483333333333334), 'log_loss': np.float64(3.069825313367081), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 5, 'accuracy': np.float64(0.4), 'precision': np.float64(0.5599999999999999), 'recall': np.float64(0.58), 'f1_score': np.float64(0.4603174603174603), 'roc_auc': np.float64(0.5866666666666667), 'log_loss': np.float64(0.8505794713548409), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 5, 'accuracy': np.float64(0.45714285714285713), 'precision': np.float64(0.5733333333333335), 'recall': np.float64(0.67), 'f1_score': np.float64(0.5357142857142857), 'roc_auc': np.float64(0.6683333333333333), 'log_loss': np.float64(0.8345841947376431), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 7, 'accuracy': np.float64(0.49523809523809526), 'precision': np.float64(0.62), 'recall': np.float64(0.73), 'f1_score': np.float64(0.5485714285714286), 'roc_auc': np.float64(0.595), 'log_loss': np.float64(0.748651650710736), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 7, 'accuracy': np.float64(0.5238095238095238), 'precision': np.float64(0.5900000000000001), 'recall': np.float64(0.72), 'f1_score': np.float64(0.5747619047619048), 'roc_auc': np.float64(0.6366666666666667), 'log_loss': np.float64(0.747613105473542), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 9, 'accuracy': np.float64(0.5238095238095238), 'precision': np.float64(0.6209523809523809), 'recall': np.float64(0.82), 'f1_score': np.float64(0.5954545454545455), 'roc_auc': np.float64(0.5491666666666667), 'log_loss': np.float64(0.7689744782106829), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 9, 'accuracy': np.float64(0.519047619047619), 'precision': np.float64(0.5942857142857143), 'recall': np.float64(0.77), 'f1_score': np.float64(0.5906926406926406), 'roc_auc': np.float64(0.675), 'log_loss': np.float64(0.7452386162850255), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 11, 'accuracy': np.float64(0.3619047619047619), 'precision': np.float64(0.5233333333333334), 'recall': np.float64(0.64), 'f1_score': np.float64(0.45095238095238094), 'roc_auc': np.float64(0.4641666666666667), 'log_loss': np.float64(0.7943625323499732), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 11, 'accuracy': np.float64(0.42857142857142855), 'precision': np.float64(0.5233333333333334), 'recall': np.float64(0.72), 'f1_score': np.float64(0.5342857142857143), 'roc_auc': np.float64(0.6683333333333333), 'log_loss': np.float64(0.7685603659427358), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 13, 'accuracy': np.float64(0.30000000000000004), 'precision': np.float64(0.2876190476190476), 'recall': np.float64(0.6), 'f1_score': np.float64(0.35974025974025975), 'roc_auc': np.float64(0.32416666666666666), 'log_loss': np.float64(0.8100294649871975), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 13, 'accuracy': np.float64(0.4238095238095238), 'precision': np.float64(0.5266666666666667), 'recall': np.float64(0.73), 'f1_score': np.float64(0.5219047619047619), 'roc_auc': np.float64(0.555), 'log_loss': np.float64(0.7827298489115312), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 15, 'accuracy': np.float64(0.30000000000000004), 'precision': np.float64(0.2876190476190476), 'recall': np.float64(0.6), 'f1_score': np.float64(0.35974025974025975), 'roc_auc': np.float64(0.24500000000000002), 'log_loss': np.float64(0.7869312657761016), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 15, 'accuracy': np.float64(0.4238095238095238), 'precision': np.float64(0.5266666666666667), 'recall': np.float64(0.73), 'f1_score': np.float64(0.5219047619047619), 'roc_auc': np.float64(0.6050000000000001), 'log_loss': np.float64(0.7638130772138625), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 17, 'accuracy': np.float64(0.3380952380952381), 'precision': np.float64(0.3), 'recall': np.float64(0.6), 'f1_score': np.float64(0.3619047619047619), 'roc_auc': np.float64(0.33333333333333337), 'log_loss': np.float64(0.7816476148207051), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 17, 'accuracy': np.float64(0.3666666666666667), 'precision': np.float64(0.49333333333333335), 'recall': np.float64(0.6799999999999999), 'f1_score': np.float64(0.4819047619047618), 'roc_auc': np.float64(0.5566666666666666), 'log_loss': np.float64(0.7622314095784437), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 19, 'accuracy': np.float64(0.3619047619047619), 'precision': np.float64(0.4), 'recall': np.float64(0.6), 'f1_score': np.float64(0.3904761904761904), 'roc_auc': np.float64(0.4333333333333333), 'log_loss': np.float64(0.7575368174414738), 'sample_size': 32}
# {'window': 28, 'range_threshold': 2, 'n_neighbors': 19, 'accuracy': np.float64(0.4238095238095238), 'precision': np.float64(0.5733333333333335), 'recall': np.float64(0.63), 'f1_score': np.float64(0.5), 'roc_auc': np.float64(0.6466666666666667), 'log_loss': np.float64(0.7485648142411273), 'sample_size': 32}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 3, 'accuracy': np.float64(0.3), 'precision': np.float64(0.06666666666666667), 'recall': np.float64(0.2), 'f1_score': np.float64(0.1), 'roc_auc': np.float64(0.325), 'log_loss': np.float64(4.3446257337342145), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 3, 'accuracy': np.float64(0.3), 'precision': np.float64(0.06666666666666667), 'recall': np.float64(0.2), 'f1_score': np.float64(0.1), 'roc_auc': np.float64(0.4083333333333334), 'log_loss': np.float64(4.447293291189609), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 5, 'accuracy': np.float64(0.4), 'precision': np.float64(0.16666666666666666), 'recall': np.float64(0.4), 'f1_score': np.float64(0.2333333333333333), 'roc_auc': np.float64(0.5), 'log_loss': np.float64(0.7946511994417057), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 5, 'accuracy': np.float64(0.3), 'precision': np.float64(0.13333333333333333), 'recall': np.float64(0.4), 'f1_score': np.float64(0.2), 'roc_auc': np.float64(0.4166666666666667), 'log_loss': np.float64(0.8843080626249682), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 7, 'accuracy': np.float64(0.35), 'precision': np.float64(0.2), 'recall': np.float64(0.1), 'f1_score': np.float64(0.13333333333333333), 'roc_auc': np.float64(0.35000000000000003), 'log_loss': np.float64(0.7445680353030676), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 7, 'accuracy': np.float64(0.25), 'precision': np.float64(0.06666666666666667), 'recall': np.float64(0.2), 'f1_score': np.float64(0.1), 'roc_auc': np.float64(0.2166666666666667), 'log_loss': np.float64(0.8340370203436729), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 9, 'accuracy': np.float64(0.6), 'precision': np.float64(0.2), 'recall': np.float64(0.1), 'f1_score': np.float64(0.13333333333333333), 'roc_auc': np.float64(0.4750000000000001), 'log_loss': np.float64(0.66934798131419), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 9, 'accuracy': np.float64(0.45), 'precision': np.float64(0.16666666666666666), 'recall': np.float64(0.3), 'f1_score': np.float64(0.2), 'roc_auc': np.float64(0.2833333333333334), 'log_loss': np.float64(0.7636743313588064), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 11, 'accuracy': np.float64(0.65), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.5666666666666667), 'log_loss': np.float64(0.6460174996314432), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 11, 'accuracy': np.float64(0.45), 'precision': np.float64(0.06666666666666667), 'recall': np.float64(0.2), 'f1_score': np.float64(0.1), 'roc_auc': np.float64(0.3), 'log_loss': np.float64(0.7396705877782555), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 13, 'accuracy': np.float64(0.65), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.5833333333333334), 'log_loss': np.float64(0.6503980953836563), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 13, 'accuracy': np.float64(0.6), 'precision': np.float64(0.1), 'recall': np.float64(0.2), 'f1_score': np.float64(0.13333333333333333), 'roc_auc': np.float64(0.3666666666666667), 'log_loss': np.float64(0.7343872525301226), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 15, 'accuracy': np.float64(0.65), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.4), 'log_loss': np.float64(0.6772466976707716), 'sample_size': 20}
# {'window': 32, 'range_threshold': 2, 'n_neighbors': 15, 'accuracy': np.float64(0.6), 'precision': np.float64(0.0), 'recall': np.float64(0.0), 'f1_score': np.float64(0.0), 'roc_auc': np.float64(0.23333333333333334), 'log_loss': np.float64(0.7421270805808904), 'sample_size': 20}
# Error processing window=32, range_threshold=2, n_neighbors=17, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 17, n_samples_fit = 16, n_samples = 4
# Error processing window=32, range_threshold=2, n_neighbors=17, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 17, n_samples_fit = 16, n_samples = 4
# Error processing window=32, range_threshold=2, n_neighbors=19, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 19, n_samples_fit = 16, n_samples = 4
# Error processing window=32, range_threshold=2, n_neighbors=19, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 19, n_samples_fit = 16, n_samples = 4
# Error processing window=36, range_threshold=2, n_neighbors=3, weights=uniform, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, n_neighbors=3, weights=distance, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, n_neighbors=5, weights=uniform, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, n_neighbors=5, weights=distance, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, n_neighbors=7, weights=uniform, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, n_neighbors=7, weights=distance, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, n_neighbors=9, weights=uniform, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, n_neighbors=9, weights=distance, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, n_neighbors=11, weights=uniform, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, n_neighbors=11, weights=distance, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=36, range_threshold=2, n_neighbors=13, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 13, n_samples_fit = 11, n_samples = 3
# Error processing window=36, range_threshold=2, n_neighbors=13, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 13, n_samples_fit = 11, n_samples = 3
# Error processing window=36, range_threshold=2, n_neighbors=15, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 15, n_samples_fit = 11, n_samples = 3
# Error processing window=36, range_threshold=2, n_neighbors=15, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 15, n_samples_fit = 11, n_samples = 3
# Error processing window=36, range_threshold=2, n_neighbors=17, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 17, n_samples_fit = 11, n_samples = 3
# Error processing window=36, range_threshold=2, n_neighbors=17, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 17, n_samples_fit = 11, n_samples = 3
# Error processing window=36, range_threshold=2, n_neighbors=19, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 19, n_samples_fit = 11, n_samples = 3
# Error processing window=36, range_threshold=2, n_neighbors=19, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 19, n_samples_fit = 11, n_samples = 3
# Error processing window=40, range_threshold=2, n_neighbors=3, weights=uniform, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, n_neighbors=3, weights=distance, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, n_neighbors=5, weights=uniform, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, n_neighbors=5, weights=distance, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, n_neighbors=7, weights=uniform, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, n_neighbors=7, weights=distance, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=40, range_threshold=2, n_neighbors=9, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 8, n_samples = 3
# Error processing window=40, range_threshold=2, n_neighbors=9, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 8, n_samples = 3
# Error processing window=40, range_threshold=2, n_neighbors=11, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 11, n_samples_fit = 8, n_samples = 3
# Error processing window=40, range_threshold=2, n_neighbors=11, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 11, n_samples_fit = 8, n_samples = 3
# Error processing window=40, range_threshold=2, n_neighbors=13, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 13, n_samples_fit = 8, n_samples = 3
# Error processing window=40, range_threshold=2, n_neighbors=13, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 13, n_samples_fit = 8, n_samples = 3
# Error processing window=40, range_threshold=2, n_neighbors=15, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 15, n_samples_fit = 8, n_samples = 3
# Error processing window=40, range_threshold=2, n_neighbors=15, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 15, n_samples_fit = 8, n_samples = 3
# Error processing window=40, range_threshold=2, n_neighbors=17, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 17, n_samples_fit = 8, n_samples = 3
# Error processing window=40, range_threshold=2, n_neighbors=17, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 17, n_samples_fit = 8, n_samples = 3
# Error processing window=40, range_threshold=2, n_neighbors=19, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 19, n_samples_fit = 8, n_samples = 3
# Error processing window=40, range_threshold=2, n_neighbors=19, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 19, n_samples_fit = 8, n_samples = 3
# Error processing window=44, range_threshold=2, n_neighbors=3, weights=uniform, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, n_neighbors=3, weights=distance, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, n_neighbors=5, weights=uniform, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, n_neighbors=5, weights=distance, metric=euclidean: y_true contains only one label (0). Please provide the true labels explicitly through the labels argument.
# Error processing window=44, range_threshold=2, n_neighbors=7, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 5, n_samples = 2
# Error processing window=44, range_threshold=2, n_neighbors=7, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 7, n_samples_fit = 5, n_samples = 2
# Error processing window=44, range_threshold=2, n_neighbors=9, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 5, n_samples = 2
# Error processing window=44, range_threshold=2, n_neighbors=9, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 9, n_samples_fit = 5, n_samples = 2
# Error processing window=44, range_threshold=2, n_neighbors=11, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 11, n_samples_fit = 5, n_samples = 2
# Error processing window=44, range_threshold=2, n_neighbors=11, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 11, n_samples_fit = 5, n_samples = 2
# Error processing window=44, range_threshold=2, n_neighbors=13, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 13, n_samples_fit = 5, n_samples = 2
# Error processing window=44, range_threshold=2, n_neighbors=13, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 13, n_samples_fit = 5, n_samples = 2
# Error processing window=44, range_threshold=2, n_neighbors=15, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 15, n_samples_fit = 5, n_samples = 2
# Error processing window=44, range_threshold=2, n_neighbors=15, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 15, n_samples_fit = 5, n_samples = 2
# Error processing window=44, range_threshold=2, n_neighbors=17, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 17, n_samples_fit = 5, n_samples = 2
# Error processing window=44, range_threshold=2, n_neighbors=17, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 17, n_samples_fit = 5, n_samples = 2
# Error processing window=44, range_threshold=2, n_neighbors=19, weights=uniform, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 19, n_samples_fit = 5, n_samples = 2
# Error processing window=44, range_threshold=2, n_neighbors=19, weights=distance, metric=euclidean: Expected n_neighbors <= n_samples_fit, but n_neighbors = 19, n_samples_fit = 5, n_samples = 2
# {'window': 12, 'range_threshold': 3, 'n_neighbors': 3, 'accuracy': np.float64(0.5116104868913858), 'precision': np.float64(0.5154682704123499), 'recall': np.float64(0.5208109987724715), 'f1_score': np.float64(0.516357471257262), 'roc_auc': np.float64(0.5066881195155313), 'log_loss': np.float64(5.222335766733574), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'n_neighbors': 3, 'accuracy': np.float64(0.5131086142322098), 'precision': np.float64(0.5169688181351636), 'recall': np.float64(0.5242307102744614), 'f1_score': np.float64(0.5186200718948337), 'roc_auc': np.float64(0.5105973926943873), 'log_loss': np.float64(5.231556522535832), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'n_neighbors': 5, 'accuracy': np.float64(0.502621722846442), 'precision': np.float64(0.5067958777333776), 'recall': np.float64(0.4916517734892089), 'f1_score': np.float64(0.49727980299553093), 'roc_auc': np.float64(0.4935636884122), 'log_loss': np.float64(1.7438363398638135), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'n_neighbors': 5, 'accuracy': np.float64(0.5041198501872659), 'precision': np.float64(0.5078401718923369), 'recall': np.float64(0.4976688836947482), 'f1_score': np.float64(0.501162041538114), 'roc_auc': np.float64(0.49891051701818034), 'log_loss': np.float64(1.7543390693615275), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'n_neighbors': 7, 'accuracy': np.float64(0.501123595505618), 'precision': np.float64(0.505464934798286), 'recall': np.float64(0.49404867483618276), 'f1_score': np.float64(0.4978660301186519), 'roc_auc': np.float64(0.4970275226207038), 'log_loss': np.float64(0.9621921951102802), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'n_neighbors': 7, 'accuracy': np.float64(0.5146067415730338), 'precision': np.float64(0.5191719885295146), 'recall': np.float64(0.5034315069163833), 'f1_score': np.float64(0.5096049158919211), 'roc_auc': np.float64(0.5044662514406799), 'log_loss': np.float64(0.9671871926340933), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'n_neighbors': 9, 'accuracy': np.float64(0.4898876404494382), 'precision': np.float64(0.4950667848568295), 'recall': np.float64(0.47485906241430553), 'f1_score': np.float64(0.4821350405755965), 'roc_auc': np.float64(0.49223361897742235), 'log_loss': np.float64(0.8187318031315846), 'sample_size': 1335}
# {'window': 12, 'range_threshold': 3, 'n_neighbors': 9, 'accuracy': np.float64(0.4966292134831461), 'precision': np.float64(0.5017159429856621), 'recall': np.float64(0.4908448279989404), 'f1_score': np.float64(0.49369945481865923), 'roc_auc': np.float64(0.5003808912006119), 'log_loss': np.float64(0.8211668552169279), 'sample_size': 1335}
# ...
# {'window': 36, 'range_threshold': 10, 'n_neighbors': 9, 'accuracy': np.float64(0.49728506787330307), 'precision': np.float64(0.5119662072744986), 'recall': np.float64(0.5421174476955931), 'f1_score': np.float64(0.524908457856245), 'roc_auc': np.float64(0.5027801122633655), 'log_loss': np.float64(0.8635981825744572), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'n_neighbors': 11, 'accuracy': np.float64(0.4891114767585356), 'precision': np.float64(0.5036073914640278), 'recall': np.float64(0.5295412790023025), 'f1_score': np.float64(0.5148067114711322), 'roc_auc': np.float64(0.500176712604156), 'log_loss': np.float64(0.8079124365666386), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'n_neighbors': 11, 'accuracy': np.float64(0.4900452488687782), 'precision': np.float64(0.5043621931761944), 'recall': np.float64(0.538440245027086), 'f1_score': np.float64(0.5195760946420606), 'roc_auc': np.float64(0.4989862408415121), 'log_loss': np.float64(0.8179853928037346), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'n_neighbors': 13, 'accuracy': np.float64(0.5045454545454545), 'precision': np.float64(0.5187641025641025), 'recall': np.float64(0.5380942991911826), 'f1_score': np.float64(0.5269075471743857), 'roc_auc': np.float64(0.5130444417470292), 'log_loss': np.float64(0.7303383375064321), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'n_neighbors': 13, 'accuracy': np.float64(0.49821061291649527), 'precision': np.float64(0.5117908408902683), 'recall': np.float64(0.5295181777281046), 'f1_score': np.float64(0.5193349576311037), 'roc_auc': np.float64(0.5074593084234678), 'log_loss': np.float64(0.7408719043880898), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'n_neighbors': 15, 'accuracy': np.float64(0.49638009049773757), 'precision': np.float64(0.5106411545310134), 'recall': np.float64(0.5423511151012497), 'f1_score': np.float64(0.5238999711596012), 'roc_auc': np.float64(0.5117280129363959), 'log_loss': np.float64(0.7227877179834918), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'n_neighbors': 15, 'accuracy': np.float64(0.4954709995886467), 'precision': np.float64(0.5089771054325973), 'recall': np.float64(0.5273290321267237), 'f1_score': np.float64(0.5168679833770817), 'roc_auc': np.float64(0.5048197876778004), 'log_loss': np.float64(0.7321983289782666), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'n_neighbors': 17, 'accuracy': np.float64(0.5009214315096668), 'precision': np.float64(0.5142847168842593), 'recall': np.float64(0.5541648269277357), 'f1_score': np.float64(0.5316193441553876), 'roc_auc': np.float64(0.5024138494710012), 'log_loss': np.float64(0.7202452037883508), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'n_neighbors': 17, 'accuracy': np.float64(0.49546277252159604), 'precision': np.float64(0.5084338995384978), 'recall': np.float64(0.5358652676751946), 'f1_score': np.float64(0.5209141625193598), 'roc_auc': np.float64(0.49866695422130203), 'log_loss': np.float64(0.7275414123770669), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'n_neighbors': 19, 'accuracy': np.float64(0.4927396133278486), 'precision': np.float64(0.5078062678062679), 'recall': np.float64(0.5560516902105206), 'f1_score': np.float64(0.5287790585882448), 'roc_auc': np.float64(0.49193696616627064), 'log_loss': np.float64(0.7218661317871007), 'sample_size': 1102}
# {'window': 36, 'range_threshold': 10, 'n_neighbors': 19, 'accuracy': np.float64(0.4945331139448787), 'precision': np.float64(0.5076376311604969), 'recall': np.float64(0.547285559973209), 'f1_score': np.float64(0.5259475914879619), 'roc_auc': np.float64(0.4923135355783971), 'log_loss': np.float64(0.7272656018772727), 'sample_size': 1102}
# {'window': 40, 'range_threshold': 10, 'n_neighbors': 3, 'accuracy': np.float64(0.4989247311827957), 'precision': np.float64(0.5091756670441019), 'recall': np.float64(0.49649714074529916), 'f1_score': np.float64(0.5024163090931186), 'roc_auc': np.float64(0.5089504986573059), 'log_loss': np.float64(4.859896764779542), 'sample_size': 932}
# {'window': 40, 'range_threshold': 10, 'n_neighbors': 3, 'accuracy': np.float64(0.4935598872980277), 'precision': np.float64(0.5039434989562868), 'recall': np.float64(0.49828410538479206), 'f1_score': np.float64(0.5007844848726678), 'roc_auc': np.float64(0.49995765562070565), 'log_loss': np.float64(4.878614068324046), 'sample_size': 932}
# {'window': 40, 'range_threshold': 10, 'n_neighbors': 5, 'accuracy': np.float64(0.5118394571905008), 'precision': np.float64(0.5198824484096762), 'recall': np.float64(0.5253299608760139), 'f1_score': np.float64(0.5223794670884899), 'roc_auc': np.float64(0.517424895480378), 'log_loss': np.float64(1.6978912247627183), 'sample_size': 932}
# {'window': 40, 'range_threshold': 10, 'n_neighbors': 5, 'accuracy': np.float64(0.5150480133402334), 'precision': np.float64(0.5233295109245725), 'recall': np.float64(0.518786804321502), 'f1_score': np.float64(0.5208909732524896), 'roc_auc': np.float64(0.509644381423451), 'log_loss': np.float64(1.714752420197997), 'sample_size': 932}
# {'window': 40, 'range_threshold': 10, 'n_neighbors':
 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'n_neighbors': 13, 'accuracy': np.float64(0.49672456575682383), 'precision': np.float64(0.5153340221480848), 'recall': np.float64(0.4855657484933058), 'f1_score': np.float64(0.49074569552051067), 'roc_auc': np.float64(0.4866930462671233), 'log_loss': np.float64(0.7643313214853953), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'n_neighbors': 13, 'accuracy': np.float64(0.49156327543424316), 'precision': np.float64(0.5084896129631736), 'recall': np.float64(0.4969972798608583), 'f1_score': np.float64(0.4940371162067625), 'roc_auc': np.float64(0.4874792405143807), 'log_loss': np.float64(0.7708180690043138), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'n_neighbors': 15, 'accuracy': np.float64(0.47353184449958635), 'precision': np.float64(0.4921105689031523), 'recall': np.float64(0.48440109412288146), 'f1_score': np.float64(0.47890101648099836), 'roc_auc': np.float64(0.4757185296619875), 'log_loss': np.float64(0.7592241495038008), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'n_neighbors': 15, 'accuracy': np.float64(0.48771712158808933), 'precision': np.float64(0.5054307251634215), 'recall': np.float64(0.5006971443595032), 'f1_score': np.float64(0.4943945675291072), 'roc_auc': np.float64(0.47965329098129733), 'log_loss': np.float64(0.7642701424120745), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'n_neighbors': 17, 'accuracy': np.float64(0.49405293631100083), 'precision': np.float64(0.5182597522519402), 'recall': np.float64(0.49620525421672124), 'f1_score': np.float64(0.4956157206299894), 'roc_auc': np.float64(0.48393273185219365), 'log_loss': np.float64(0.7492094803513706), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'n_neighbors': 17, 'accuracy': np.float64(0.49409429280397016), 'precision': np.float64(0.5151693522167915), 'recall': np.float64(0.5094267382599199), 'f1_score': np.float64(0.5015872647620655), 'roc_auc': np.float64(0.4860206928090031), 'log_loss': np.float64(0.7546181303744277), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'n_neighbors': 19, 'accuracy': np.float64(0.49277915632754343), 'precision': np.float64(0.5136042676537034), 'recall': np.float64(0.4962994276584557), 'f1_score': np.float64(0.4927826068528116), 'roc_auc': np.float64(0.49722270470468777), 'log_loss': np.float64(0.73983497210559), 'sample_size': 777}
# {'window': 44, 'range_threshold': 10, 'n_neighbors': 19, 'accuracy': np.float64(0.4954011579818031), 'precision': np.float64(0.5153562519351993), 'recall': np.float64(0.4937912571289892), 'f1_score': np.float64(0.49239997074098457), 'roc_auc': np.float64(0.49449962806454223), 'log_loss': np.float64(0.7457245368526981), 'sample_size': 777}

# %%
print(final_results_df_knn.shape)
precision_knn = final_results_df_knn[final_results_df_knn['sample_size'] >= 300].sort_values(by='precision', ascending=False)
precision_knn.iloc[0:5]
# Out:
# (1400, 10)
#      window  range_threshold  n_neighbors  accuracy  precision    recall  \
# 750      44                6           19  0.547272   0.585346  0.677823
# 334      24                4           17  0.562767   0.582471  0.597402
# 336      24                4           19  0.562731   0.581658  0.598549
# 353      28                4           17  0.572961   0.581274  0.553774
# 744      44                6           13  0.553423   0.580652  0.687674
#
#      f1_score   roc_auc  log_loss  sample_size
# 750  0.619181  0.533086  0.719774          316
# 334  0.585143  0.560594  0.708194          526
# 336  0.585860  0.564067  0.702880          526
# 353  0.565108  0.551177  0.723984          349
# 744  0.624154  0.551801  0.714428          316

# %%
# final_results_df_knn = pd.read_csv('final_results_df_knn.csv')
